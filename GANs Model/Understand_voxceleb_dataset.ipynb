# %%
import numpy as np

from PIL import Image
from torch.utils.data import Dataset

def load_voice(voice_item):
    voice_data = np.load(voice_item['filepath'])
    voice_data = voice_data.T.astype('float32')
    voice_label = voice_item['label_id']
    print("Loading voice data: ", voice_data, voice_label)
    return voice_data, voice_label

def load_face(face_item):
    face_data = Image.open(face_item['filepath']).convert('RGB').resize([64, 64])
    face_data = np.transpose(np.array(face_data), (2, 0, 1))
    face_data = ((face_data - 127.5) / 127.5).astype('float32')
    face_label = face_item['label_id']
    print("Loading face data: ", face_data, face_label)
    return face_data, face_label

class VoiceDataset(Dataset):
    def __init__(self, voice_list, nframe_range):
        self.voice_list = voice_list
        self.crop_nframe = nframe_range[1]

    def __getitem__(self, index):
        voice_data, voice_label = load_voice(self.voice_list[index])
        assert self.crop_nframe <= voice_data.shape[1]
        pt = np.random.randint(voice_data.shape[1] - self.crop_nframe + 1)
        voice_data = voice_data[:, pt:pt+self.crop_nframe]
        return voice_data, voice_label

    def __len__(self):
        return len(self.voice_list)

class FaceDataset(Dataset):
    def __init__(self, face_list):
        self.face_list = face_list

    def __getitem__(self, index):
        face_data, face_label = load_face(self.face_list[index])
        if np.random.random() > 0.5:
           face_data = np.flip(face_data, axis=2).copy()
        return face_data, face_label

    def __len__(self):
        return len(self.face_list)

# %%
import string
from dataset import VoiceDataset, FaceDataset
from network import VoiceEmbedNet, Generator, FaceEmbedNet, Classifier
from utils import get_collate_fn

DATASET_PARAMETERS = {
    # meta data provided by voxceleb1 dataset
    'meta_file': 'voxCeleb-Dataset\\vox1_meta.csv',

    # voice dataset
    'voice_dir': 'voxCeleb-Dataset\\fbank\\fbank',
    'voice_ext': 'npy',

    # face dataset
    'face_dir': 'voxCeleb-Dataset\\VGG_ALL_FRONTAL\\VGG_ALL_FRONTAL',
    'face_ext': '.jpg',

    # train data includes the identities
    # whose names start with the characters of 'FGH...XYZ'
    'split': string.ascii_uppercase[5:],

    # dataloader
    'voice_dataset': VoiceDataset,
    'face_dataset': FaceDataset,
    'batch_size': 128,
    'nframe_range': [300, 800],
    'workers_num': 1,
    'collate_fn': get_collate_fn,

    # test data
    'test_data': 'data\\example_data'
}


NETWORKS_PARAMETERS = {
    # VOICE EMBEDDING NETWORK (e)
    'e': {
        'network': VoiceEmbedNet,
        'input_channel': 64,
        'channels': [256, 384, 576, 864],
        'output_channel': 64,  # the embedding dimension
        'model_path': 'pretrained_models/voice_embedding.pth',
    },
    # GENERATOR (g)
    'g': {
        'network': Generator,
        'input_channel': 64,
        # channels for deconvolutional layers
        'channels': [1024, 512, 256, 128, 64],
        'output_channel': 3,  # images with RGB channels
        'model_path': 'models/generator.pth',
    },
    # FACE EMBEDDING NETWORK (f)
    'f': {
        'network': FaceEmbedNet,
        'input_channel': 3,
        'channels': [32, 64, 128, 256, 512],
        'output_channel': 64,
        'model_path': 'models/face_embedding.pth',
    },
    # DISCRIMINATOR (d)
    'd': {
        'network': Classifier,  # Discrminator is a special Classifier with 1 subject
        'input_channel': 64,
        'channels': [],
        'output_channel': 1,
        'model_path': 'models/discriminator.pth',
    },
    # CLASSIFIER (c)
    'c': {
        'network': Classifier,
        'input_channel': 64,
        'channels': [],
        'output_channel': -1,  # This parameter is depended on the dataset we used
        'model_path': 'models/classifier.pth',
    },
    # OPTIMIZER PARAMETERS
    'lr': 0.0002,
    'beta1': 0.5,
    'beta2': 0.999,

    # MODE, use GPU or not
    'GPU': True


}

# %%
import os

def parse_metafile(meta_file):
    with open(meta_file, 'r') as f:
        lines = f.readlines()[1:]
    celeb_ids = {}
    for line in lines:
        ID, name, _, _, _ = line.rstrip().split('\t')
        celeb_ids[ID] = name
    return celeb_ids

def get_labels(voice_list, face_list):
    voice_names = {item['name'] for item in voice_list}
    face_names = {item['name'] for item in face_list}
    names = voice_names & face_names

    voice_list = [item for item in voice_list if item['name'] in names]
    face_list = [item for item in face_list if item['name'] in names]

    names = sorted(list(names))
    label_dict = dict(zip(names, range(len(names))))
    for item in voice_list+face_list:
        item['label_id'] = label_dict[item['name']]
    return voice_list, face_list, len(names)
    

def get_dataset_files(data_dir, data_ext, celeb_ids, split):
    data_list = []
    # read data directory
    for root, dirs, filenames in os.walk(data_dir):
        for filename in filenames:
            if filename.endswith(data_ext):
                filepath = os.path.join(root, filename)
                # so hacky, be careful! 
                folder = filepath[len(data_dir):].split('\\')[1]
                celeb_name = celeb_ids.get(folder, folder)
                if celeb_name.startswith(tuple(split)):
                    data_list.append({'filepath': filepath, 'name': celeb_name})
    return data_list

def get_dataset(data_params):
    celeb_ids = parse_metafile(data_params['meta_file'])
    
    voice_list = get_dataset_files(data_params['voice_dir'],
                                   data_params['voice_ext'],
                                   celeb_ids,
                                   data_params['split'])
    face_list = get_dataset_files(data_params['face_dir'],
                                  data_params['face_ext'],
                                  celeb_ids,
                                  data_params['split'])
    return get_labels(voice_list, face_list)

# %%
# dataset and dataloader
print('Parsing your dataset...')
voice_list, face_list, id_class_num = get_dataset(DATASET_PARAMETERS)
print("voice",voice_list[0],len(voice_list))
print("face",face_list[0],len(face_list))
print("id_class_num",id_class_num)
NETWORKS_PARAMETERS['c']['output_channel'] = id_class_num
# Out:
# Parsing your dataset...
# voice {'filepath': 'voxCeleb-Dataset\\fbank\\fbank\\id10310\\aJdH3chi5sE\\00001.npy', 'name': 'Fanny_Ardant', 'label_id': 0} 113322
# face {'filepath': 'voxCeleb-Dataset\\VGG_ALL_FRONTAL\\VGG_ALL_FRONTAL\\Fanny_Ardant\\00000021.jpg', 'name': 'Fanny_Ardant', 'label_id': 0} 106584
# id_class_num 924

# %%
print('Preparing the datasets...')
voice_dataset = DATASET_PARAMETERS['voice_dataset'](voice_list,DATASET_PARAMETERS['nframe_range'])
face_dataset = DATASET_PARAMETERS['face_dataset'](face_list)
# Out:
# Preparing the datasets...

# %%
import os
import time
import torch
import torch.nn.functional as F

from torch.utils.data import DataLoader
from network import get_network
from utils import Meter, cycle, save_model

# %%
print('Preparing the dataloaders...')
collate_fn = DATASET_PARAMETERS['collate_fn'](DATASET_PARAMETERS['nframe_range'])
voice_loader = DataLoader(voice_dataset, shuffle=True, drop_last=True,
                          batch_size=DATASET_PARAMETERS['batch_size'],
                          num_workers=DATASET_PARAMETERS['workers_num']
                          )
face_loader = DataLoader(face_dataset, shuffle=True, drop_last=True,
                         batch_size=DATASET_PARAMETERS['batch_size'],
                         num_workers=DATASET_PARAMETERS['workers_num'])
# Out:
# Preparing the dataloaders...

# %%
voice_iterator = iter(cycle(voice_loader))
face_iterator = iter(cycle(face_loader))

# %%
device = torch.device("cuda")
device
# Out:
# device(type='cuda')

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class VoiceEmbedNet(nn.Module):
    def __init__(self, input_channel, channels, output_channel):
        super(VoiceEmbedNet, self).__init__()
        self.model = nn.Sequential(
            nn.Conv1d(input_channel, channels[0], 3, 2, 1, bias=False),
            nn.BatchNorm1d(channels[0], affine=True),
            nn.ReLU(inplace=True),
            nn.Conv1d(channels[0], channels[1], 3, 2, 1, bias=False),
            nn.BatchNorm1d(channels[1], affine=True),
            nn.ReLU(inplace=True),
            nn.Conv1d(channels[1], channels[2], 3, 2, 1, bias=False),
            nn.BatchNorm1d(channels[2], affine=True),
            nn.ReLU(inplace=True),
            nn.Conv1d(channels[2], channels[3], 3, 2, 1, bias=False),
            nn.BatchNorm1d(channels[3], affine=True),
            nn.ReLU(inplace=True),
            nn.Conv1d(channels[3], output_channel, 3, 2, 1, bias=True),
        )

    def forward(self, x):
        x = self.model(x)
        x = F.avg_pool1d(x, x.size()[2], stride=1)
        x = x.view(x.size()[0], -1, 1, 1)
        return x

class Generator(nn.Module):
    def __init__(self, input_channel, channels, output_channel):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.ConvTranspose2d(input_channel, channels[0], 4, 1, 0, bias=True),
            nn.BatchNorm1d(channels[0], affine=True),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(channels[0], channels[1], 4, 2, 1, bias=True),
            nn.BatchNorm1d(channels[1], affine=True),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(channels[1], channels[2], 4, 2, 1, bias=True),
            nn.BatchNorm1d(channels[2], affine=True),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(channels[2], channels[3], 4, 2, 1, bias=True),
            nn.BatchNorm1d(channels[3], affine=True),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(channels[3], channels[4], 4, 2, 1, bias=True),
            nn.BatchNorm1d(channels[4], affine=True),
            nn.ReLU(inplace=True),
            
            nn.ConvTranspose2d(channels[4], output_channel, 1, 1, 0, bias=True),
            nn.Tanh()
        )
    def forward(self, x):
        x = self.model(x)
        return x

class FaceEmbedNet(nn.Module):
    def __init__(self, input_channel, channels, output_channel):
        super(FaceEmbedNet, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(input_channel, channels[0], 1, 1, 0, bias=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(channels[0], channels[1], 4, 2, 1, bias=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(channels[1], channels[2], 4, 2, 1, bias=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(channels[2], channels[3], 4, 2, 1, bias=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(channels[3], channels[4], 4, 2, 1, bias=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(channels[4], output_channel, 4, 1, 0, bias=True),
        )
 
    def forward(self, x):
        x = self.model(x)
        return x

class Classifier(nn.Module):
    def __init__(self, input_channel, channels, output_channel):
        super(Classifier, self).__init__()
        self.model = nn.Linear(input_channel, output_channel, bias=False)

    def forward(self, x):
        x = x.view(x.size()[0], -1)
        x = self.model(x)
        return x

def get_network(net_type, params, train=True):
    net_params = params[net_type]
    net = net_params['network'](net_params['input_channel'],
                                net_params['channels'],
                                net_params['output_channel'])

    if params['GPU']:
        net.cuda()

    if train:
        if net_params['model_path'] is not None:
            print('load model from {}'.format(net_params['model_path']))
            net.load_state_dict(torch.load(net_params['model_path'],map_location=torch.device('cpu')))
        net.train()
        optimizer = optim.RMSprop(net.parameters(),lr=params['lr'],alpha=0.9,eps=1e-08,weight_decay=0, momentum=0, centered=False)
        #optimizer = optim.Adam(net.parameters(), lr=params['lr'], betas=(params['beta1'], params['beta2']))
    else:
        net.eval()
        print('load model from {}'.format(net_params['model_path']))
        net.load_state_dict(torch.load(net_params['model_path'],map_location=torch.device('cpu')))
        optimizer = None
        
    return net, optimizer

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# networks, Fe, Fg, Fd (f+d), Fc (f+c)
print('Initializing networks...')
e_net, e_optimizer = get_network('e', NETWORKS_PARAMETERS, train=False) #voice embed
g_net, g_optimizer = get_network('g', NETWORKS_PARAMETERS, train=True) #generator
f_net, f_optimizer = get_network('f', NETWORKS_PARAMETERS, train=True) #face embed
d_net, d_optimizer = get_network('d', NETWORKS_PARAMETERS, train=True) #discriminator
c_net, c_optimizer = get_network('c', NETWORKS_PARAMETERS, train=True) #classifier
# Out:
# Initializing networks...
# load model from pretrained_models/voice_embedding.pth
# load model from models/generator.pth
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 4
#       2 print('Initializing networks...')
#       3 e_net, e_optimizer = get_network('e', NETWORKS_PARAMETERS, train=False) #voice embed
# ----> 4 g_net, g_optimizer = get_network('g', NETWORKS_PARAMETERS, train=True) #generator
#       5 f_net, f_optimizer = get_network('f', NETWORKS_PARAMETERS, train=True) #face embed
#       6 d_net, d_optimizer = get_network('d', NETWORKS_PARAMETERS, train=True) #discriminator
#
# Cell In[5], line 106, in get_network(net_type, params, train)
#     104 if net_params['model_path'] is not None:
#     105     print('load model from {}'.format(net_params['model_path']))
# --> 106     net.load_state_dict(torch.load(net_params['model_path'],map_location=torch.device('cpu')))
#     107 net.train()
#     108 optimizer = optim.RMSprop(net.parameters(),lr=params['lr'],alpha=0.9,eps=1e-08,weight_decay=0, momentum=0, centered=False)
#
# File c:\Users\Ahmed\.conda\envs\tensorflow-gpu\lib\site-packages\torch\nn\modules\module.py:1671, in Module.load_state_dict(self, state_dict, strict)
#    1666         error_msgs.insert(
#    1667             0, 'Missing key(s) in state_dict: {}. '.format(
#    1668                 ', '.join('"{}"'.format(k) for k in missing_keys)))
#    1670 if len(error_msgs) > 0:
# -> 1671     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1672                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    1673 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for Generator:
# 	Missing key(s) in state_dict: "model.1.weight", "model.1.bias", "model.1.running_mean", "model.1.running_var", "model.3.weight", "model.3.bias", "model.4.running_mean", "model.4.running_var", "model.7.weight", "model.7.bias", "model.7.running_mean", "model.7.running_var", "model.9.weight", "model.9.bias", "model.10.running_mean", "model.10.running_var", "model.12.weight", "model.12.bias", "model.13.weight", "model.13.bias", "model.13.running_mean", "model.13.running_var", "model.15.weight", "model.15.bias".
# 	Unexpected key(s) in state_dict: "model.2.weight", "model.2.bias", "model.8.weight", "model.8.bias".
# 	size mismatch for model.4.weight: copying a param with shape torch.Size([512, 256, 4, 4]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for model.4.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([512]).
# 	size mismatch for model.6.weight: copying a param with shape torch.Size([256, 128, 4, 4]) from checkpoint, the shape in current model is torch.Size([512, 256, 4, 4]).
# 	size mismatch for model.6.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([256]).
# 	size mismatch for model.10.weight: copying a param with shape torch.Size([64, 3, 1, 1]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for model.10.bias: copying a param with shape torch.Size([3]) from checkpoint, the shape in current model is torch.Size([128]).

# %%
# label for real/fake faces
real_label = torch.full((DATASET_PARAMETERS['batch_size'], 1), 1)
fake_label = torch.full((DATASET_PARAMETERS['batch_size'], 1), 0)

# %%
# Meters for recording the training status
iteration = Meter('Iter', 'sum', ':5d')
data_time = Meter('Data', 'sum', ':4.2f')
batch_time = Meter('Time', 'sum', ':4.2f')
D_real = Meter('D_real', 'avg', ':3.2f')
D_fake = Meter('D_fake', 'avg', ':3.2f')
C_real = Meter('C_real', 'avg', ':3.2f')
GD_fake = Meter('G_D_fake', 'avg', ':3.2f')
GC_fake = Meter('G_C_fake', 'avg', ':3.2f')

# %%
generator_losses = []
discriminator_losses = []
x_axis = []
times = []

# %%
import pandas as pd

dict = {'Epoch': x_axis, 'Generator loss': generator_losses, 'Discriminator loss': discriminator_losses}
df = pd.DataFrame(dict)
df
# Out:
# Empty DataFrame
# Columns: [Epoch, Generator loss, Discriminator loss]
# Index: []

# %%
print('Training models...')
for it in range(1000):
    # data
    start_time = time.time()
    
    x_axis.append(it)
    
    voice, voice_label = next(voice_iterator)
    face, face_label = next(face_iterator)
    noise = 0.05*torch.randn(DATASET_PARAMETERS['batch_size'], 64, 1, 1)

    # use GPU or not
    
    if NETWORKS_PARAMETERS['GPU']: 
        voice, voice_label = voice.cuda(), voice_label.cuda()
        face, face_label = face.cuda(), face_label.cuda()
        real_label, fake_label = real_label.cuda(), fake_label.cuda()
        noise = noise.cuda()
    data_time.update(time.time() - start_time)
    
    # get embeddings and generated faces
    embeddings = e_net(voice)
    embeddings = F.normalize(embeddings)
    # introduce some permutations
    embeddings = embeddings + noise
    embeddings = F.normalize(embeddings)
    fake = g_net(embeddings)

    # Discriminator
    f_optimizer.zero_grad()
    d_optimizer.zero_grad()
    c_optimizer.zero_grad()
    real_score_out = d_net(f_net(face))
    fake_score_out = d_net(f_net(fake.detach()))
    real_label_out = c_net(f_net(face))
    D_real_loss = F.binary_cross_entropy(torch.sigmoid(real_score_out), real_label.type(torch.cuda.FloatTensor))
    D_fake_loss = F.binary_cross_entropy(torch.sigmoid(fake_score_out), fake_label.type(torch.cuda.FloatTensor))
    C_real_loss = F.nll_loss(F.log_softmax(real_label_out, 1), face_label)
    D_real.update(D_real_loss.item())
    D_fake.update(D_fake_loss.item())
    C_real.update(C_real_loss.item())
    
    discriminator_losses.append((D_real_loss + D_fake_loss + C_real_loss).item())
    
    (D_real_loss + D_fake_loss + C_real_loss).backward()
    f_optimizer.step()
    d_optimizer.step()
    c_optimizer.step()

    # Generator
    g_optimizer.zero_grad()
    fake_score_out = d_net(f_net(fake))
    fake_label_out = c_net(f_net(fake))
    GD_fake_loss = F.binary_cross_entropy(torch.sigmoid(fake_score_out), real_label.type(torch.cuda.FloatTensor))
    GC_fake_loss = F.nll_loss(F.log_softmax(fake_label_out, 1), voice_label)
    
    generator_losses.append((GD_fake_loss + GC_fake_loss).item())
    
    (GD_fake_loss + GC_fake_loss).backward()
    GD_fake.update(GD_fake_loss.item())
    GC_fake.update(GC_fake_loss.item())
    g_optimizer.step()

    times.append(time.time() - start_time)
    
    batch_time.update(time.time() - start_time)
    df = pd.DataFrame({'Epoch': x_axis,'Generator loss': generator_losses, 'Discriminator loss': discriminator_losses})
    # print status
    if it % 5 == 0:
        print(iteration, data_time, batch_time,D_real, D_fake, C_real, GD_fake, GC_fake)
        data_time.reset()
        batch_time.reset()
        D_real.reset()
        D_fake.reset()
        C_real.reset()
        GD_fake.reset()
        GC_fake.reset()
        # snapshot
        save_model(g_net, NETWORKS_PARAMETERS['g']['model_path'])
        save_model(f_net, NETWORKS_PARAMETERS['f']['model_path'])
        save_model(d_net, NETWORKS_PARAMETERS['d']['model_path'])
        save_model(c_net, NETWORKS_PARAMETERS['c']['model_path'])
        df.to_csv('loss.csv', index=False, header=True)
    iteration.update(1)
# Out:
# Training models...
# Iter:    0, Data:13.92, Time:18.61, D_real:0.69, D_fake:0.70, C_real:6.83, G_D_fake:0.70, G_C_fake:6.83,
# Iter:    1, Data:0.02, Time:1.06, D_real:0.68, D_fake:0.69, C_real:6.83, G_D_fake:0.72, G_C_fake:6.83,
# Iter:    2, Data:0.02, Time:1.06, D_real:0.65, D_fake:0.66, C_real:6.83, G_D_fake:0.80, G_C_fake:6.83,
# Iter:    3, Data:2.80, Time:3.82, D_real:0.55, D_fake:0.60, C_real:6.83, G_D_fake:1.08, G_C_fake:6.82,
# Iter:    4, Data:7.01, Time:8.04, D_real:0.37, D_fake:0.42, C_real:6.82, G_D_fake:1.88, G_C_fake:6.85,
# Iter:    5, Data:2.97, Time:4.09, D_real:0.18, D_fake:0.18, C_real:6.90, G_D_fake:4.23, G_C_fake:6.89,
# Iter:    6, Data:3.13, Time:4.16, D_real:0.25, D_fake:0.02, C_real:7.00, G_D_fake:0.63, G_C_fake:6.84,
# Iter:    7, Data:5.73, Time:6.76, D_real:0.01, D_fake:1.05, C_real:7.22, G_D_fake:5.91, G_C_fake:7.08,
# Iter:    8, Data:3.45, Time:4.48, D_real:0.94, D_fake:0.01, C_real:6.92, G_D_fake:4.08, G_C_fake:7.01,
# Iter:    9, Data:3.92, Time:4.95, D_real:0.61, D_fake:0.27, C_real:6.92, G_D_fake:1.54, G_C_fake:6.86,
# Iter:   10, Data:6.02, Time:7.05, D_real:0.52, D_fake:2.70, C_real:6.87, G_D_fake:0.36, G_C_fake:6.84,
# Iter:   11, Data:3.08, Time:4.12, D_real:0.58, D_fake:1.72, C_real:6.83, G_D_fake:0.57, G_C_fake:6.83,
# Iter:   12, Data:3.52, Time:4.69, D_real:0.67, D_fake:0.87, C_real:6.83, G_D_fake:0.80, G_C_fake:6.84,
# Iter:   13, Data:2.93, Time:3.97, D_real:0.63, D_fake:0.59, C_real:6.82, G_D_fake:0.99, G_C_fake:6.83,
# Iter:   14, Data:3.57, Time:4.60, D_real:0.61, D_fake:0.47, C_real:6.81, G_D_fake:1.22, G_C_fake:6.85,
# Iter:   15, Data:13.16, Time:14.19, D_real:0.62, D_fake:0.38, C_real:6.83, G_D_fake:1.42, G_C_fake:6.82,
# Iter:   16, Data:2.83, Time:3.87, D_real:0.56, D_fake:0.33, C_real:6.83, G_D_fake:1.51, G_C_fake:6.83,
# Iter:   17, Data:3.06, Time:4.09, D_real:0.46, D_fake:0.35, C_real:6.85, G_D_fake:1.41, G_C_fake:6.84,
# Iter:   18, Data:3.40, Time:4.43, D_real:0.35, D_fake:0.54, C_real:6.85, G_D_fake:1.30, G_C_fake:6.84,
# Iter:   19, Data:7.38, Time:8.60, D_real:0.33, D_fake:1.13, C_real:6.83, G_D_fake:0.98, G_C_fake:6.84,
# Iter:   20, Data:4.87, Time:5.91, D_real:0.50, D_fake:1.35, C_real:6.84, G_D_fake:0.64, G_C_fake:6.83,
# Iter:   21, Data:2.83, Time:3.86, D_real:0.61, D_fake:1.02, C_real:6.80, G_D_fake:0.66, G_C_fake:6.83,
# Iter:   22, Data:4.10, Time:5.14, D_real:0.54, D_fake:0.75, C_real:6.83, G_D_fake:0.78, G_C_fake:6.83,
# Iter:   23, Data:10.05, Time:11.08, D_real:0.46, D_fake:0.61, C_real:6.83, G_D_fake:0.90, G_C_fake:6.84,
# Iter:   24, Data:7.21, Time:8.25, D_real:0.42, D_fake:0.52, C_real:6.83, G_D_fake:1.04, G_C_fake:6.82,
# Iter:   25, Data:5.69, Time:6.85, D_real:0.36, D_fake:0.44, C_real:6.82, G_D_fake:1.21, G_C_fake:6.81,
# Iter:   26, Data:9.00, Time:10.03, D_real:0.26, D_fake:0.37, C_real:6.83, G_D_fake:1.47, G_C_fake:6.85,
# Iter:   27, Data:2.75, Time:3.78, D_real:0.19, D_fake:0.31, C_real:6.85, G_D_fake:1.81, G_C_fake:6.85,
# Iter:   28, Data:5.39, Time:6.43, D_real:0.16, D_fake:0.33, C_real:6.90, G_D_fake:2.04, G_C_fake:6.85,
# Iter:   29, Data:9.05, Time:10.08, D_real:0.16, D_fake:0.66, C_real:6.93, G_D_fake:2.02, G_C_fake:6.84,
# Iter:   30, Data:8.92, Time:9.95, D_real:0.41, D_fake:0.57, C_real:6.85, G_D_fake:2.32, G_C_fake:6.90,
# Iter:   31, Data:7.42, Time:8.56, D_real:0.26, D_fake:0.12, C_real:6.88, G_D_fake:3.07, G_C_fake:6.92,
# Iter:   32, Data:7.16, Time:8.19, D_real:0.06, D_fake:0.06, C_real:6.95, G_D_fake:3.78, G_C_fake:7.01,
# Iter:   33, Data:2.77, Time:3.80, D_real:0.04, D_fake:0.04, C_real:7.04, G_D_fake:4.18, G_C_fake:7.08,
# Iter:   34, Data:8.81, Time:9.85, D_real:0.08, D_fake:0.04, C_real:6.89, G_D_fake:3.73, G_C_fake:6.93,
# Iter:   35, Data:6.06, Time:7.09, D_real:0.10, D_fake:0.07, C_real:6.96, G_D_fake:3.34, G_C_fake:6.95,
# Iter:   36, Data:13.00, Time:14.13, D_real:0.07, D_fake:0.14, C_real:6.93, G_D_fake:4.97, G_C_fake:7.03,
# Iter:   37, Data:7.52, Time:8.55, D_real:0.28, D_fake:0.06, C_real:6.85, G_D_fake:2.60, G_C_fake:6.93,
# Iter:   38, Data:3.07, Time:4.11, D_real:0.06, D_fake:1.08, C_real:6.95, G_D_fake:5.90, G_C_fake:7.06,
# Iter:   39, Data:5.20, Time:6.24, D_real:1.42, D_fake:0.01, C_real:6.86, G_D_fake:2.65, G_C_fake:6.88,
# Iter:   40, Data:2.88, Time:3.91, D_real:0.07, D_fake:0.11, C_real:6.91, G_D_fake:1.98, G_C_fake:6.82,
# Iter:   41, Data:8.77, Time:9.80, D_real:0.03, D_fake:0.21, C_real:6.98, G_D_fake:2.58, G_C_fake:6.92,
# Iter:   42, Data:2.95, Time:3.98, D_real:0.07, D_fake:0.10, C_real:6.92, G_D_fake:3.31, G_C_fake:6.92,
# Iter:   43, Data:3.21, Time:4.39, D_real:0.11, D_fake:0.05, C_real:6.86, G_D_fake:3.74, G_C_fake:6.95,
# Iter:   44, Data:10.05, Time:11.08, D_real:0.13, D_fake:0.05, C_real:6.94, G_D_fake:3.75, G_C_fake:6.89,
# Iter:   45, Data:5.62, Time:6.66, D_real:0.13, D_fake:0.08, C_real:6.92, G_D_fake:3.76, G_C_fake:6.91,
# Iter:   46, Data:14.29, Time:15.33, D_real:0.17, D_fake:0.10, C_real:6.89, G_D_fake:4.47, G_C_fake:6.88,
# Iter:   47, Data:16.38, Time:17.62, D_real:0.15, D_fake:0.06, C_real:6.93, G_D_fake:5.04, G_C_fake:7.09,
# Iter:   48, Data:3.09, Time:4.12, D_real:0.21, D_fake:0.07, C_real:6.86, G_D_fake:5.43, G_C_fake:7.01,
# Iter:   49, Data:3.73, Time:4.76, D_real:0.17, D_fake:0.02, C_real:6.84, G_D_fake:5.56, G_C_fake:7.04,
# Iter:   50, Data:10.57, Time:11.61, D_real:0.13, D_fake:0.01, C_real:6.90, G_D_fake:5.30, G_C_fake:7.08,
# Iter:   51, Data:3.46, Time:4.50, D_real:0.10, D_fake:0.03, C_real:6.83, G_D_fake:5.31, G_C_fake:7.11,
# Iter:   52, Data:9.73, Time:10.76, D_real:0.05, D_fake:0.02, C_real:6.86, G_D_fake:5.85, G_C_fake:7.14,
# Iter:   53, Data:5.20, Time:6.38, D_real:0.06, D_fake:0.06, C_real:6.83, G_D_fake:6.96, G_C_fake:7.16,
# Iter:   54, Data:11.36, Time:12.40, D_real:0.06, D_fake:0.50, C_real:6.86, G_D_fake:9.60, G_C_fake:7.58,
# Iter:   55, Data:3.26, Time:4.30, D_real:0.20, D_fake:0.00, C_real:6.85, G_D_fake:10.51, G_C_fake:7.41,
# Iter:   56, Data:3.19, Time:4.22, D_real:0.15, D_fake:0.00, C_real:6.90, G_D_fake:10.81, G_C_fake:7.41,
# Iter:   57, Data:11.86, Time:12.90, D_real:0.11, D_fake:0.00, C_real:6.84, G_D_fake:10.08, G_C_fake:7.66,
# Iter:   58, Data:6.63, Time:7.77, D_real:0.08, D_fake:0.00, C_real:6.86, G_D_fake:7.33, G_C_fake:7.20,
# Iter:   59, Data:3.11, Time:4.14, D_real:0.05, D_fake:0.03, C_real:6.85, G_D_fake:4.40, G_C_fake:6.97,
# Iter:   60, Data:3.28, Time:4.32, D_real:0.06, D_fake:0.25, C_real:6.90, G_D_fake:4.15, G_C_fake:7.00,
# Iter:   61, Data:12.22, Time:13.26, D_real:0.08, D_fake:0.14, C_real:6.87, G_D_fake:5.31, G_C_fake:7.08,
# Iter:   62, Data:4.15, Time:5.18, D_real:0.21, D_fake:0.18, C_real:6.84, G_D_fake:6.38, G_C_fake:7.09,
# Iter:   63, Data:15.59, Time:16.74, D_real:0.36, D_fake:0.16, C_real:6.83, G_D_fake:5.91, G_C_fake:7.15,
# Iter:   64, Data:7.69, Time:8.72, D_real:0.23, D_fake:0.04, C_real:6.85, G_D_fake:4.06, G_C_fake:6.93,
# Iter:   65, Data:3.62, Time:4.65, D_real:0.11, D_fake:0.14, C_real:6.93, G_D_fake:4.54, G_C_fake:6.99,
# Iter:   66, Data:5.19, Time:6.22, D_real:0.12, D_fake:0.04, C_real:6.92, G_D_fake:4.60, G_C_fake:6.99,
# Iter:   67, Data:3.80, Time:4.83, D_real:0.12, D_fake:0.02, C_real:6.85, G_D_fake:4.30, G_C_fake:6.97,
# Iter:   68, Data:8.17, Time:9.20, D_real:0.09, D_fake:0.04, C_real:6.90, G_D_fake:3.95, G_C_fake:7.01,
# Iter:   69, Data:3.33, Time:4.37, D_real:0.13, D_fake:0.12, C_real:6.87, G_D_fake:3.73, G_C_fake:6.94,
# Iter:   70, Data:3.37, Time:4.49, D_real:0.17, D_fake:0.26, C_real:6.83, G_D_fake:3.88, G_C_fake:6.97,
# Iter:   71, Data:13.61, Time:14.64, D_real:0.13, D_fake:0.09, C_real:6.86, G_D_fake:4.42, G_C_fake:6.95,
# Iter:   72, Data:3.14, Time:4.18, D_real:0.18, D_fake:0.03, C_real:6.88, G_D_fake:3.69, G_C_fake:6.92,
# Iter:   73, Data:6.30, Time:7.34, D_real:0.15, D_fake:0.07, C_real:6.86, G_D_fake:4.03, G_C_fake:7.00,
# Iter:   74, Data:4.75, Time:5.78, D_real:0.13, D_fake:0.04, C_real:6.83, G_D_fake:4.04, G_C_fake:6.95,
# Iter:   75, Data:8.00, Time:9.17, D_real:0.11, D_fake:0.04, C_real:6.89, G_D_fake:3.94, G_C_fake:6.98,
# Iter:   76, Data:3.66, Time:4.68, D_real:0.10, D_fake:0.07, C_real:6.84, G_D_fake:4.66, G_C_fake:7.03,
# Iter:   77, Data:9.63, Time:10.66, D_real:0.17, D_fake:0.06, C_real:6.87, G_D_fake:4.74, G_C_fake:7.02,
# Iter:   78, Data:10.16, Time:11.19, D_real:0.09, D_fake:0.16, C_real:6.89, G_D_fake:6.67, G_C_fake:7.09,
# Iter:   79, Data:5.94, Time:6.98, D_real:0.41, D_fake:0.01, C_real:6.84, G_D_fake:2.98, G_C_fake:6.88,
# Iter:   80, Data:7.95, Time:9.08, D_real:0.08, D_fake:0.13, C_real:6.88, G_D_fake:5.37, G_C_fake:6.98,
# Iter:   81, Data:6.57, Time:7.60, D_real:0.17, D_fake:0.02, C_real:6.88, G_D_fake:5.03, G_C_fake:7.04,
# Iter:   82, Data:11.05, Time:12.08, D_real:0.10, D_fake:0.02, C_real:6.86, G_D_fake:4.26, G_C_fake:7.07,
# Iter:   83, Data:5.83, Time:6.87, D_real:0.14, D_fake:0.11, C_real:6.79, G_D_fake:7.07, G_C_fake:7.15,
# Iter:   84, Data:15.54, Time:16.57, D_real:0.30, D_fake:0.01, C_real:6.86, G_D_fake:2.75, G_C_fake:6.86,
# Iter:   85, Data:4.25, Time:5.37, D_real:0.12, D_fake:0.67, C_real:6.82, G_D_fake:18.22, G_C_fake:8.76,
# Iter:   86, Data:3.89, Time:4.92, D_real:2.55, D_fake:0.00, C_real:6.94, G_D_fake:7.69, G_C_fake:7.13,
# Iter:   87, Data:13.49, Time:14.52, D_real:0.23, D_fake:0.09, C_real:6.96, G_D_fake:3.13, G_C_fake:6.90,
# Iter:   88, Data:10.12, Time:11.16, D_real:0.09, D_fake:1.39, C_real:6.87, G_D_fake:5.63, G_C_fake:7.02,
# Iter:   89, Data:5.02, Time:6.06, D_real:0.23, D_fake:0.01, C_real:6.79, G_D_fake:6.21, G_C_fake:7.03,
# Iter:   90, Data:17.46, Time:18.68, D_real:0.33, D_fake:0.02, C_real:6.81, G_D_fake:5.54, G_C_fake:6.96,
# Iter:   91, Data:11.86, Time:12.90, D_real:0.24, D_fake:0.05, C_real:6.82, G_D_fake:4.04, G_C_fake:6.87,
# Iter:   92, Data:4.95, Time:5.98, D_real:0.21, D_fake:0.14, C_real:6.84, G_D_fake:2.64, G_C_fake:6.85,
# Iter:   93, Data:5.05, Time:6.08, D_real:0.16, D_fake:0.17, C_real:6.86, G_D_fake:3.11, G_C_fake:6.85,
# Iter:   94, Data:18.32, Time:19.46, D_real:0.20, D_fake:0.08, C_real:6.80, G_D_fake:3.58, G_C_fake:6.93,
# Iter:   95, Data:4.90, Time:5.93, D_real:0.13, D_fake:0.06, C_real:6.87, G_D_fake:3.68, G_C_fake:6.89,
# Iter:   96, Data:4.01, Time:5.04, D_real:0.27, D_fake:0.08, C_real:6.82, G_D_fake:3.24, G_C_fake:6.93,
# Iter:   97, Data:17.88, Time:18.91, D_real:0.17, D_fake:0.11, C_real:6.83, G_D_fake:3.48, G_C_fake:6.94,
# Iter:   98, Data:4.76, Time:5.79, D_real:0.15, D_fake:0.08, C_real:6.79, G_D_fake:3.92, G_C_fake:6.93,
# Iter:   99, Data:5.20, Time:6.35, D_real:0.14, D_fake:0.06, C_real:6.91, G_D_fake:4.03, G_C_fake:6.86,
# Iter:  100, Data:6.61, Time:7.65, D_real:0.25, D_fake:0.05, C_real:6.78, G_D_fake:3.80, G_C_fake:6.90,
# Iter:  101, Data:6.55, Time:7.58, D_real:0.09, D_fake:0.03, C_real:6.75, G_D_fake:4.23, G_C_fake:7.03,
# Iter:  102, Data:6.13, Time:7.17, D_real:0.11, D_fake:0.02, C_real:6.87, G_D_fake:4.37, G_C_fake:6.96,
# Iter:  103, Data:5.01, Time:6.05, D_real:0.09, D_fake:0.02, C_real:6.82, G_D_fake:4.24, G_C_fake:7.03,
# Iter:  104, Data:8.31, Time:9.47, D_real:0.06, D_fake:0.03, C_real:6.84, G_D_fake:4.04, G_C_fake:7.00,
# Iter:  105, Data:5.73, Time:6.76, D_real:0.05, D_fake:0.10, C_real:6.85, G_D_fake:4.94, G_C_fake:7.11,
# Iter:  106, Data:4.36, Time:5.39, D_real:0.10, D_fake:0.02, C_real:6.84, G_D_fake:5.66, G_C_fake:7.08,
# Iter:  107, Data:5.45, Time:6.49, D_real:0.07, D_fake:0.02, C_real:6.74, G_D_fake:5.71, G_C_fake:7.03,
# Iter:  108, Data:3.96, Time:4.99, D_real:0.10, D_fake:0.03, C_real:6.82, G_D_fake:4.48, G_C_fake:7.03,
# Iter:  109, Data:4.81, Time:5.84, D_real:0.05, D_fake:0.12, C_real:6.79, G_D_fake:4.49, G_C_fake:6.99,
# Iter:  110, Data:8.02, Time:9.06, D_real:0.10, D_fake:0.31, C_real:6.72, G_D_fake:3.75, G_C_fake:6.90,
# Iter:  111, Data:19.38, Time:20.61, D_real:0.14, D_fake:0.12, C_real:6.78, G_D_fake:4.21, G_C_fake:6.90,
# Iter:  112, Data:24.35, Time:25.38, D_real:0.28, D_fake:0.04, C_real:6.78, G_D_fake:2.48, G_C_fake:6.94,
# Iter:  113, Data:10.83, Time:11.95, D_real:0.07, D_fake:0.25, C_real:6.82, G_D_fake:2.64, G_C_fake:6.83,
# Iter:  114, Data:4.17, Time:5.20, D_real:0.12, D_fake:0.19, C_real:6.84, G_D_fake:3.29, G_C_fake:6.84,
# Iter:  115, Data:20.59, Time:21.62, D_real:0.15, D_fake:0.08, C_real:6.81, G_D_fake:2.91, G_C_fake:6.91,
# Iter:  116, Data:22.70, Time:23.84, D_real:0.08, D_fake:0.13, C_real:6.82, G_D_fake:2.87, G_C_fake:6.90,
# Iter:  117, Data:8.73, Time:9.77, D_real:0.11, D_fake:0.15, C_real:6.83, G_D_fake:3.38, G_C_fake:6.94,
# Iter:  118, Data:4.53, Time:5.56, D_real:0.16, D_fake:0.10, C_real:6.83, G_D_fake:2.88, G_C_fake:6.89,
# Iter:  119, Data:15.59, Time:16.62, D_real:0.12, D_fake:0.16, C_real:6.91, G_D_fake:3.25, G_C_fake:6.85,
# Iter:  120, Data:8.27, Time:9.42, D_real:0.15, D_fake:0.11, C_real:6.81, G_D_fake:3.05, G_C_fake:6.90,
# Iter:  121, Data:4.51, Time:5.54, D_real:0.15, D_fake:0.11, C_real:6.77, G_D_fake:2.92, G_C_fake:6.87,
# Iter:  122, Data:10.29, Time:11.32, D_real:0.10, D_fake:0.10, C_real:6.84, G_D_fake:3.38, G_C_fake:6.93,
# Iter:  123, Data:8.22, Time:9.25, D_real:0.14, D_fake:0.06, C_real:6.67, G_D_fake:3.00, G_C_fake:6.90,
# Iter:  124, Data:4.77, Time:5.81, D_real:0.07, D_fake:0.11, C_real:6.80, G_D_fake:3.75, G_C_fake:7.00,
# Iter:  125, Data:17.86, Time:19.03, D_real:0.21, D_fake:0.06, C_real:6.78, G_D_fake:2.51, G_C_fake:6.90,
# Iter:  126, Data:5.50, Time:6.53, D_real:0.04, D_fake:0.27, C_real:6.89, G_D_fake:6.39, G_C_fake:7.06,
# Iter:  127, Data:22.76, Time:23.79, D_real:0.94, D_fake:0.01, C_real:6.81, G_D_fake:0.34, G_C_fake:6.91,
# Iter:  128, Data:66.89, Time:68.02, D_real:0.03, D_fake:1.83, C_real:6.87, G_D_fake:1.30, G_C_fake:6.91,
# Iter:  129, Data:5.10, Time:6.24, D_real:0.10, D_fake:0.51, C_real:6.80, G_D_fake:2.48, G_C_fake:6.90,
# Iter:  130, Data:5.98, Time:7.02, D_real:0.43, D_fake:0.17, C_real:6.75, G_D_fake:2.31, G_C_fake:6.84,
# Iter:  131, Data:16.13, Time:17.17, D_real:0.49, D_fake:0.16, C_real:6.83, G_D_fake:1.72, G_C_fake:6.89,
# Iter:  132, Data:7.29, Time:8.32, D_real:0.27, D_fake:0.30, C_real:6.79, G_D_fake:1.58, G_C_fake:6.84,
# Iter:  133, Data:5.12, Time:6.15, D_real:0.19, D_fake:0.30, C_real:6.73, G_D_fake:2.07, G_C_fake:6.90,
# Iter:  134, Data:4.49, Time:5.67, D_real:0.19, D_fake:0.21, C_real:6.76, G_D_fake:2.45, G_C_fake:6.91,
# Iter:  135, Data:13.95, Time:14.99, D_real:0.26, D_fake:0.17, C_real:6.70, G_D_fake:2.62, G_C_fake:6.93,
# Iter:  136, Data:4.71, Time:5.75, D_real:0.22, D_fake:0.18, C_real:6.80, G_D_fake:2.93, G_C_fake:6.82,
# Iter:  137, Data:6.03, Time:7.06, D_real:0.27, D_fake:0.20, C_real:6.78, G_D_fake:2.87, G_C_fake:6.90,
# Iter:  138, Data:16.48, Time:17.65, D_real:0.28, D_fake:0.20, C_real:6.76, G_D_fake:2.83, G_C_fake:6.87,
# Iter:  139, Data:4.04, Time:5.08, D_real:0.28, D_fake:0.30, C_real:6.83, G_D_fake:3.46, G_C_fake:6.93,
# Iter:  140, Data:4.33, Time:5.36, D_real:0.96, D_fake:0.16, C_real:6.75, G_D_fake:0.70, G_C_fake:6.82,
# Iter:  141, Data:6.12, Time:7.15, D_real:0.20, D_fake:1.44, C_real:6.71, G_D_fake:7.26, G_C_fake:7.08,
# Iter:  142, Data:16.53, Time:17.57, D_real:2.71, D_fake:0.19, C_real:6.87, G_D_fake:0.70, G_C_fake:6.88,
# Iter:  143, Data:7.36, Time:8.51, D_real:0.17, D_fake:0.85, C_real:6.75, G_D_fake:2.82, G_C_fake:6.92,
# Iter:  144, Data:4.27, Time:5.31, D_real:0.33, D_fake:0.15, C_real:6.77, G_D_fake:2.96, G_C_fake:6.97,
# Iter:  145, Data:13.14, Time:14.17, D_real:0.54, D_fake:0.63, C_real:6.78, G_D_fake:1.30, G_C_fake:6.83,
# Iter:  146, Data:4.83, Time:5.87, D_real:0.40, D_fake:1.19, C_real:6.75, G_D_fake:0.87, G_C_fake:6.84,
# Iter:  147, Data:11.62, Time:12.66, D_real:0.40, D_fake:0.76, C_real:6.81, G_D_fake:1.19, G_C_fake:6.83,
# Iter:  148, Data:6.64, Time:7.85, D_real:0.40, D_fake:0.43, C_real:6.82, G_D_fake:1.63, G_C_fake:6.83,
# Iter:  149, Data:17.62, Time:18.65, D_real:0.31, D_fake:0.25, C_real:6.78, G_D_fake:2.19, G_C_fake:6.83,
# Iter:  150, Data:13.92, Time:15.09, D_real:0.26, D_fake:0.18, C_real:6.78, G_D_fake:2.58, G_C_fake:6.86,
# Iter:  151, Data:29.02, Time:30.05, D_real:0.21, D_fake:0.17, C_real:6.76, G_D_fake:2.81, G_C_fake:6.82,
# Iter:  152, Data:5.96, Time:7.15, D_real:0.20, D_fake:0.24, C_real:6.75, G_D_fake:2.82, G_C_fake:6.85,
# Iter:  153, Data:4.11, Time:5.15, D_real:0.19, D_fake:0.49, C_real:6.80, G_D_fake:2.55, G_C_fake:6.88,
# Iter:  154, Data:7.66, Time:8.69, D_real:0.30, D_fake:0.66, C_real:6.77, G_D_fake:2.38, G_C_fake:6.88,
# Iter:  155, Data:17.66, Time:18.70, D_real:0.58, D_fake:0.42, C_real:6.77, G_D_fake:4.51, G_C_fake:6.90,
# Iter:  156, Data:6.48, Time:7.51, D_real:0.70, D_fake:0.02, C_real:6.77, G_D_fake:2.81, G_C_fake:6.86,
# Iter:  157, Data:5.27, Time:6.39, D_real:0.29, D_fake:0.20, C_real:6.76, G_D_fake:2.16, G_C_fake:6.86,
# Iter:  158, Data:11.97, Time:13.00, D_real:0.24, D_fake:0.70, C_real:6.80, G_D_fake:4.42, G_C_fake:6.93,
# Iter:  159, Data:3.88, Time:4.91, D_real:0.80, D_fake:0.17, C_real:6.84, G_D_fake:1.82, G_C_fake:6.84,
# Iter:  160, Data:21.51, Time:22.54, D_real:0.42, D_fake:0.42, C_real:6.78, G_D_fake:2.22, G_C_fake:6.85,
# Iter:  161, Data:62.04, Time:63.27, D_real:0.36, D_fake:0.26, C_real:6.79, G_D_fake:3.08, G_C_fake:6.95,
# Iter:  162, Data:4.23, Time:5.40, D_real:0.46, D_fake:0.16, C_real:6.81, G_D_fake:2.76, G_C_fake:6.89,
# Iter:  163, Data:4.60, Time:5.64, D_real:0.36, D_fake:0.40, C_real:6.83, G_D_fake:2.86, G_C_fake:6.93,
# Iter:  164, Data:4.17, Time:5.21, D_real:0.68, D_fake:0.61, C_real:6.80, G_D_fake:2.35, G_C_fake:6.86,
# Iter:  165, Data:19.88, Time:20.92, D_real:0.96, D_fake:0.41, C_real:6.78, G_D_fake:2.65, G_C_fake:6.85,
# Iter:  166, Data:7.75, Time:8.85, D_real:0.60, D_fake:0.23, C_real:6.79, G_D_fake:2.96, G_C_fake:6.91,
# Iter:  167, Data:4.61, Time:5.64, D_real:0.49, D_fake:0.48, C_real:6.75, G_D_fake:2.46, G_C_fake:6.90,
# Iter:  168, Data:11.64, Time:12.67, D_real:0.75, D_fake:0.72, C_real:6.78, G_D_fake:1.17, G_C_fake:6.84,
# Iter:  169, Data:8.50, Time:9.53, D_real:0.52, D_fake:0.51, C_real:6.80, G_D_fake:1.67, G_C_fake:6.85,
# Iter:  170, Data:4.41, Time:5.44, D_real:0.28, D_fake:0.30, C_real:6.81, G_D_fake:2.31, G_C_fake:6.86,
# Iter:  171, Data:18.23, Time:19.37, D_real:0.29, D_fake:0.19, C_real:6.79, G_D_fake:2.52, G_C_fake:6.83,
# Iter:  172, Data:7.89, Time:8.91, D_real:0.26, D_fake:0.33, C_real:6.79, G_D_fake:2.52, G_C_fake:6.85,
# Iter:  173, Data:39.60, Time:40.77, D_real:0.45, D_fake:0.65, C_real:6.77, G_D_fake:3.00, G_C_fake:6.85,
# Iter:  174, Data:9.88, Time:10.92, D_real:0.97, D_fake:0.16, C_real:6.81, G_D_fake:1.78, G_C_fake:6.85,
# Iter:  175, Data:6.18, Time:7.21, D_real:0.51, D_fake:0.40, C_real:6.80, G_D_fake:2.75, G_C_fake:6.79,
# Iter:  176, Data:4.84, Time:5.87, D_real:0.48, D_fake:0.17, C_real:6.76, G_D_fake:2.12, G_C_fake:6.80,
# Iter:  177, Data:19.43, Time:20.62, D_real:0.25, D_fake:0.43, C_real:6.82, G_D_fake:2.72, G_C_fake:6.84,
# Iter:  178, Data:5.34, Time:6.38, D_real:0.55, D_fake:0.53, C_real:6.79, G_D_fake:2.03, G_C_fake:6.86,
# Iter:  179, Data:10.75, Time:11.78, D_real:0.68, D_fake:0.65, C_real:6.78, G_D_fake:1.63, G_C_fake:6.85,
# Iter:  180, Data:18.85, Time:20.04, D_real:0.53, D_fake:0.39, C_real:6.76, G_D_fake:1.63, G_C_fake:6.83,
# Iter:  181, Data:12.22, Time:13.25, D_real:0.30, D_fake:0.32, C_real:6.77, G_D_fake:1.74, G_C_fake:6.81,
# Iter:  182, Data:4.57, Time:5.61, D_real:0.28, D_fake:0.38, C_real:6.80, G_D_fake:1.94, G_C_fake:6.89,
# Iter:  183, Data:12.91, Time:13.94, D_real:0.24, D_fake:0.49, C_real:6.77, G_D_fake:2.53, G_C_fake:6.86,
# Iter:  184, Data:11.89, Time:13.07, D_real:0.54, D_fake:0.44, C_real:6.79, G_D_fake:2.27, G_C_fake:6.85,
# Iter:  185, Data:22.55, Time:23.58, D_real:0.76, D_fake:0.48, C_real:6.78, G_D_fake:2.32, G_C_fake:6.87,
# Iter:  186, Data:13.53, Time:14.70, D_real:0.85, D_fake:0.24, C_real:6.78, G_D_fake:1.18, G_C_fake:6.85,
# Iter:  187, Data:9.30, Time:10.34, D_real:0.17, D_fake:0.64, C_real:6.82, G_D_fake:4.26, G_C_fake:6.94,
# Iter:  188, Data:10.47, Time:11.50, D_real:0.72, D_fake:0.07, C_real:6.84, G_D_fake:1.92, G_C_fake:6.84,
# Iter:  189, Data:20.06, Time:21.17, D_real:0.26, D_fake:0.72, C_real:6.81, G_D_fake:1.92, G_C_fake:6.86,
# Iter:  190, Data:12.05, Time:13.09, D_real:0.52, D_fake:0.54, C_real:6.80, G_D_fake:1.84, G_C_fake:6.83,
# Iter:  191, Data:7.74, Time:8.77, D_real:0.64, D_fake:0.45, C_real:6.85, G_D_fake:1.47, G_C_fake:6.83,
# Iter:  192, Data:5.43, Time:6.47, D_real:0.42, D_fake:0.53, C_real:6.80, G_D_fake:1.79, G_C_fake:6.86,
# Iter:  193, Data:14.46, Time:15.59, D_real:0.39, D_fake:0.41, C_real:6.82, G_D_fake:2.15, G_C_fake:6.82,
# Iter:  194, Data:16.80, Time:17.83, D_real:0.58, D_fake:0.35, C_real:6.81, G_D_fake:1.91, G_C_fake:6.83,
# Iter:  195, Data:6.66, Time:7.70, D_real:0.61, D_fake:0.56, C_real:6.79, G_D_fake:2.41, G_C_fake:6.88,
# Iter:  196, Data:7.38, Time:8.42, D_real:0.90, D_fake:0.25, C_real:6.81, G_D_fake:1.34, G_C_fake:6.84,
# Iter:  197, Data:13.05, Time:14.31, D_real:0.31, D_fake:0.58, C_real:6.79, G_D_fake:2.92, G_C_fake:6.90,
# Iter:  198, Data:22.75, Time:23.78, D_real:0.55, D_fake:0.13, C_real:6.80, G_D_fake:2.47, G_C_fake:6.87,
# Iter:  199, Data:22.15, Time:23.35, D_real:0.29, D_fake:0.29, C_real:6.82, G_D_fake:2.29, G_C_fake:6.83,
# Iter:  200, Data:4.89, Time:5.92, D_real:0.29, D_fake:0.40, C_real:6.83, G_D_fake:2.46, G_C_fake:6.88,
# Iter:  201, Data:4.57, Time:5.61, D_real:0.48, D_fake:0.31, C_real:6.85, G_D_fake:1.75, G_C_fake:6.81,
# Iter:  202, Data:9.74, Time:10.77, D_real:0.21, D_fake:0.33, C_real:6.84, G_D_fake:2.11, G_C_fake:6.88,
# Iter:  203, Data:9.40, Time:10.62, D_real:0.13, D_fake:0.23, C_real:6.77, G_D_fake:2.99, G_C_fake:6.85,
# Iter:  204, Data:6.97, Time:8.00, D_real:0.20, D_fake:0.17, C_real:6.81, G_D_fake:3.10, G_C_fake:6.87,
# Iter:  205, Data:8.31, Time:9.35, D_real:0.20, D_fake:0.51, C_real:6.85, G_D_fake:6.62, G_C_fake:6.91,
# Iter:  206, Data:14.52, Time:15.55, D_real:1.91, D_fake:0.01, C_real:6.94, G_D_fake:0.52, G_C_fake:6.87,
# Iter:  207, Data:7.58, Time:8.80, D_real:0.30, D_fake:2.19, C_real:6.85, G_D_fake:3.00, G_C_fake:6.87,
# Iter:  208, Data:5.95, Time:6.99, D_real:1.20, D_fake:0.11, C_real:6.83, G_D_fake:2.21, G_C_fake:6.86,
# Iter:  209, Data:58.53, Time:59.74, D_real:0.77, D_fake:0.21, C_real:6.84, G_D_fake:1.47, G_C_fake:6.84,
# Iter:  210, Data:4.92, Time:5.94, D_real:0.48, D_fake:0.37, C_real:6.80, G_D_fake:1.24, G_C_fake:6.84,
# Iter:  211, Data:4.80, Time:5.84, D_real:0.38, D_fake:0.46, C_real:6.80, G_D_fake:1.24, G_C_fake:6.81,
# Iter:  212, Data:7.17, Time:8.20, D_real:0.37, D_fake:0.46, C_real:6.83, G_D_fake:1.32, G_C_fake:6.84,
# Iter:  213, Data:16.33, Time:17.50, D_real:0.35, D_fake:0.41, C_real:6.78, G_D_fake:1.56, G_C_fake:6.84,
# Iter:  214, Data:12.43, Time:13.47, D_real:0.32, D_fake:0.37, C_real:6.81, G_D_fake:1.64, G_C_fake:6.81,
# Iter:  215, Data:6.46, Time:7.50, D_real:0.35, D_fake:0.36, C_real:6.81, G_D_fake:1.65, G_C_fake:6.84,
# Iter:  216, Data:10.86, Time:11.89, D_real:0.31, D_fake:0.44, C_real:6.79, G_D_fake:1.70, G_C_fake:6.84,
# Iter:  217, Data:10.51, Time:11.69, D_real:0.41, D_fake:0.47, C_real:6.79, G_D_fake:1.72, G_C_fake:6.86,
# Iter:  218, Data:9.80, Time:10.83, D_real:0.55, D_fake:0.48, C_real:6.78, G_D_fake:1.71, G_C_fake:6.86,
# Iter:  219, Data:4.53, Time:5.57, D_real:0.66, D_fake:0.46, C_real:6.77, G_D_fake:1.43, G_C_fake:6.83,
# Iter:  220, Data:23.60, Time:24.71, D_real:0.51, D_fake:0.67, C_real:6.79, G_D_fake:1.85, G_C_fake:6.84,
# Iter:  221, Data:23.83, Time:24.87, D_real:0.80, D_fake:0.39, C_real:6.81, G_D_fake:1.48, G_C_fake:6.85,
# Iter:  222, Data:12.66, Time:13.82, D_real:0.58, D_fake:0.52, C_real:6.79, G_D_fake:1.68, G_C_fake:6.86,
# Iter:  223, Data:13.29, Time:14.33, D_real:0.49, D_fake:0.37, C_real:6.77, G_D_fake:1.99, G_C_fake:6.83,
# Iter:  224, Data:11.01, Time:12.05, D_real:0.49, D_fake:0.26, C_real:6.78, G_D_fake:2.05, G_C_fake:6.88,
# Iter:  225, Data:19.10, Time:20.26, D_real:0.32, D_fake:0.25, C_real:6.79, G_D_fake:2.29, G_C_fake:6.83,
# Iter:  226, Data:16.07, Time:17.10, D_real:0.39, D_fake:0.23, C_real:6.79, G_D_fake:2.09, G_C_fake:6.85,
# Iter:  227, Data:5.19, Time:6.23, D_real:0.21, D_fake:0.31, C_real:6.78, G_D_fake:2.90, G_C_fake:6.80,
# Iter:  228, Data:4.85, Time:5.89, D_real:0.47, D_fake:0.20, C_real:6.81, G_D_fake:2.00, G_C_fake:6.88,
# Iter:  229, Data:16.59, Time:17.78, D_real:0.39, D_fake:0.46, C_real:6.83, G_D_fake:2.76, G_C_fake:6.87,
# Iter:  230, Data:6.39, Time:7.43, D_real:0.46, D_fake:0.24, C_real:6.78, G_D_fake:2.51, G_C_fake:6.85,
# Iter:  231, Data:30.54, Time:31.58, D_real:0.41, D_fake:0.43, C_real:6.76, G_D_fake:2.91, G_C_fake:6.94,
# Iter:  232, Data:149.75, Time:150.96, D_real:0.72, D_fake:0.32, C_real:6.77, G_D_fake:2.11, G_C_fake:6.81,
# Iter:  233, Data:4.25, Time:5.29, D_real:0.43, D_fake:0.61, C_real:6.77, G_D_fake:3.78, G_C_fake:6.94,
# Iter:  234, Data:4.65, Time:5.68, D_real:1.03, D_fake:0.15, C_real:6.85, G_D_fake:0.96, G_C_fake:6.82,
# Iter:  235, Data:16.26, Time:17.30, D_real:0.20, D_fake:1.21, C_real:6.81, G_D_fake:2.04, G_C_fake:6.84,
# Iter:  236, Data:12.93, Time:14.03, D_real:0.62, D_fake:0.32, C_real:6.81, G_D_fake:1.72, G_C_fake:6.85,
# Iter:  237, Data:5.44, Time:6.48, D_real:0.57, D_fake:0.34, C_real:6.79, G_D_fake:1.21, G_C_fake:6.83,
# Iter:  238, Data:6.12, Time:7.16, D_real:0.23, D_fake:0.58, C_real:6.81, G_D_fake:1.54, G_C_fake:6.86,
# Iter:  239, Data:16.75, Time:17.78, D_real:0.38, D_fake:0.43, C_real:6.76, G_D_fake:1.79, G_C_fake:6.84,
# Iter:  240, Data:10.25, Time:11.40, D_real:0.45, D_fake:0.39, C_real:6.74, G_D_fake:1.93, G_C_fake:6.86,
# Iter:  241, Data:5.38, Time:6.41, D_real:0.48, D_fake:0.36, C_real:6.79, G_D_fake:1.80, G_C_fake:6.83,
# Iter:  242, Data:4.12, Time:5.15, D_real:0.42, D_fake:0.44, C_real:6.79, G_D_fake:2.53, G_C_fake:6.89,
# Iter:  243, Data:6.37, Time:7.41, D_real:0.60, D_fake:0.19, C_real:6.75, G_D_fake:1.21, G_C_fake:6.80,
# Iter:  244, Data:4.27, Time:5.30, D_real:0.23, D_fake:1.10, C_real:6.74, G_D_fake:4.40, G_C_fake:6.91,
# Iter:  245, Data:4.29, Time:5.33, D_real:1.89, D_fake:0.05, C_real:6.84, G_D_fake:1.21, G_C_fake:6.85,
# Iter:  246, Data:16.05, Time:17.22, D_real:0.31, D_fake:0.64, C_real:6.79, G_D_fake:0.87, G_C_fake:6.85,
# Iter:  247, Data:5.74, Time:6.78, D_real:0.25, D_fake:0.93, C_real:6.79, G_D_fake:1.24, G_C_fake:6.83,
# Iter:  248, Data:4.12, Time:5.15, D_real:0.38, D_fake:0.51, C_real:6.82, G_D_fake:1.66, G_C_fake:6.84,
# Iter:  249, Data:5.77, Time:6.80, D_real:0.59, D_fake:0.31, C_real:6.86, G_D_fake:1.66, G_C_fake:6.82,
# Iter:  250, Data:19.58, Time:20.76, D_real:0.58, D_fake:0.33, C_real:6.79, G_D_fake:1.45, G_C_fake:6.86,
# Iter:  251, Data:78.21, Time:79.34, D_real:0.44, D_fake:0.41, C_real:6.83, G_D_fake:1.44, G_C_fake:6.84,
# Iter:  252, Data:3.89, Time:4.92, D_real:0.43, D_fake:0.51, C_real:6.76, G_D_fake:1.62, G_C_fake:6.84,
# Iter:  253, Data:5.72, Time:6.75, D_real:0.48, D_fake:0.59, C_real:6.77, G_D_fake:1.84, G_C_fake:6.85,
# Iter:  254, Data:11.50, Time:12.67, D_real:0.70, D_fake:0.65, C_real:6.82, G_D_fake:1.84, G_C_fake:6.84,
# Iter:  255, Data:6.23, Time:7.26, D_real:0.91, D_fake:0.69, C_real:6.78, G_D_fake:1.44, G_C_fake:6.85,
# Iter:  256, Data:4.22, Time:5.25, D_real:1.08, D_fake:0.72, C_real:6.83, G_D_fake:1.08, G_C_fake:6.84,
# Iter:  257, Data:16.67, Time:17.70, D_real:0.78, D_fake:0.90, C_real:6.80, G_D_fake:1.14, G_C_fake:6.82,
# Iter:  258, Data:5.77, Time:6.82, D_real:0.64, D_fake:0.52, C_real:6.81, G_D_fake:1.19, G_C_fake:6.85,
# Iter:  259, Data:10.61, Time:11.82, D_real:0.40, D_fake:0.48, C_real:6.78, G_D_fake:1.33, G_C_fake:6.85,
# Iter:  260, Data:11.45, Time:12.48, D_real:0.33, D_fake:0.48, C_real:6.75, G_D_fake:1.63, G_C_fake:6.85,
# Iter:  261, Data:8.80, Time:9.83, D_real:0.32, D_fake:0.41, C_real:6.78, G_D_fake:1.84, G_C_fake:6.83,
# Iter:  262, Data:19.16, Time:20.32, D_real:0.44, D_fake:0.43, C_real:6.77, G_D_fake:1.99, G_C_fake:6.85,
# Iter:  263, Data:19.53, Time:20.56, D_real:0.58, D_fake:0.39, C_real:6.78, G_D_fake:1.76, G_C_fake:6.87,
# Iter:  264, Data:12.48, Time:13.51, D_real:0.59, D_fake:0.63, C_real:6.76, G_D_fake:3.00, G_C_fake:6.89,
# Iter:  265, Data:7.43, Time:8.53, D_real:1.24, D_fake:0.15, C_real:6.77, G_D_fake:0.48, G_C_fake:6.87,
# Iter:  266, Data:18.83, Time:19.86, D_real:0.21, D_fake:1.72, C_real:6.77, G_D_fake:2.04, G_C_fake:6.84,
# Iter:  267, Data:7.31, Time:8.35, D_real:0.78, D_fake:0.31, C_real:6.79, G_D_fake:1.53, G_C_fake:6.86,
# Iter:  268, Data:4.35, Time:5.39, D_real:0.69, D_fake:0.45, C_real:6.80, G_D_fake:0.97, G_C_fake:6.85,
# Iter:  269, Data:18.58, Time:19.74, D_real:0.46, D_fake:0.67, C_real:6.77, G_D_fake:0.86, G_C_fake:6.83,
# Iter:  270, Data:16.75, Time:17.79, D_real:0.37, D_fake:0.70, C_real:6.76, G_D_fake:1.03, G_C_fake:6.84,
# Iter:  271, Data:4.50, Time:5.54, D_real:0.36, D_fake:0.56, C_real:6.77, G_D_fake:1.29, G_C_fake:6.83,
# Iter:  272, Data:20.67, Time:21.79, D_real:0.44, D_fake:0.41, C_real:6.79, G_D_fake:1.40, G_C_fake:6.82,
# Iter:  273, Data:5.35, Time:6.38, D_real:0.36, D_fake:0.43, C_real:6.76, G_D_fake:1.45, G_C_fake:6.84,
# Iter:  274, Data:21.66, Time:22.69, D_real:0.44, D_fake:0.67, C_real:6.76, G_D_fake:1.96, G_C_fake:6.88,
# Iter:  275, Data:18.28, Time:19.47, D_real:0.76, D_fake:0.43, C_real:6.77, G_D_fake:1.67, G_C_fake:6.85,
# Iter:  276, Data:10.12, Time:11.15, D_real:0.74, D_fake:0.52, C_real:6.78, G_D_fake:1.36, G_C_fake:6.83,
# Iter:  277, Data:10.51, Time:11.54, D_real:0.74, D_fake:0.65, C_real:6.81, G_D_fake:1.45, G_C_fake:6.85,
# Iter:  278, Data:13.61, Time:14.65, D_real:0.79, D_fake:0.54, C_real:6.82, G_D_fake:1.22, G_C_fake:6.84,
# Iter:  279, Data:13.06, Time:14.30, D_real:0.57, D_fake:0.54, C_real:6.77, G_D_fake:1.37, G_C_fake:6.82,
# Iter:  280, Data:4.46, Time:5.50, D_real:0.41, D_fake:0.42, C_real:6.77, G_D_fake:1.61, G_C_fake:6.86,
# Iter:  281, Data:5.82, Time:6.85, D_real:0.38, D_fake:0.54, C_real:6.78, G_D_fake:1.91, G_C_fake:6.85,
# Iter:  282, Data:21.29, Time:22.32, D_real:0.59, D_fake:0.47, C_real:6.82, G_D_fake:1.72, G_C_fake:6.85,
# Iter:  283, Data:7.93, Time:9.10, D_real:0.68, D_fake:0.48, C_real:6.78, G_D_fake:1.62, G_C_fake:6.84,
# Iter:  284, Data:4.53, Time:5.57, D_real:0.60, D_fake:0.51, C_real:6.76, G_D_fake:1.60, G_C_fake:6.86,
# Iter:  285, Data:4.02, Time:5.06, D_real:0.66, D_fake:0.45, C_real:6.82, G_D_fake:1.48, G_C_fake:6.84,
# Iter:  286, Data:11.49, Time:12.53, D_real:0.52, D_fake:0.56, C_real:6.80, G_D_fake:1.52, G_C_fake:6.85,
# Iter:  287, Data:3.54, Time:4.58, D_real:0.63, D_fake:0.57, C_real:6.81, G_D_fake:1.21, G_C_fake:6.80,
# Iter:  288, Data:19.24, Time:20.43, D_real:0.56, D_fake:0.68, C_real:6.79, G_D_fake:1.19, G_C_fake:6.85,
# Iter:  289, Data:17.76, Time:18.79, D_real:0.66, D_fake:0.61, C_real:6.77, G_D_fake:1.03, G_C_fake:6.84,
# Iter:  290, Data:13.52, Time:14.56, D_real:0.54, D_fake:0.62, C_real:6.78, G_D_fake:1.09, G_C_fake:6.83,
# Iter:  291, Data:9.31, Time:10.51, D_real:0.37, D_fake:0.54, C_real:6.75, G_D_fake:1.42, G_C_fake:6.86,
# Iter:  292, Data:20.82, Time:21.86, D_real:0.42, D_fake:0.43, C_real:6.75, G_D_fake:1.42, G_C_fake:6.85,
# Iter:  293, Data:10.78, Time:11.81, D_real:0.35, D_fake:0.48, C_real:6.75, G_D_fake:1.62, G_C_fake:6.85,
# Iter:  294, Data:4.15, Time:5.33, D_real:0.39, D_fake:0.40, C_real:6.77, G_D_fake:1.91, G_C_fake:6.87,
# Iter:  295, Data:3.97, Time:5.01, D_real:0.44, D_fake:0.37, C_real:6.73, G_D_fake:2.15, G_C_fake:6.88,
# Iter:  296, Data:15.51, Time:16.55, D_real:0.48, D_fake:0.29, C_real:6.79, G_D_fake:1.61, G_C_fake:6.86,
# Iter:  297, Data:6.76, Time:7.80, D_real:0.29, D_fake:0.55, C_real:6.73, G_D_fake:3.56, G_C_fake:6.89,
# Iter:  298, Data:9.00, Time:10.04, D_real:0.87, D_fake:0.22, C_real:6.81, G_D_fake:1.34, G_C_fake:6.87,
# Iter:  299, Data:5.75, Time:6.94, D_real:0.38, D_fake:1.73, C_real:6.75, G_D_fake:3.39, G_C_fake:6.93,
# Iter:  300, Data:16.62, Time:17.65, D_real:1.34, D_fake:0.15, C_real:6.79, G_D_fake:1.32, G_C_fake:6.85,
# Iter:  301, Data:10.83, Time:11.99, D_real:0.53, D_fake:0.50, C_real:6.78, G_D_fake:0.79, G_C_fake:6.84,
# Iter:  302, Data:7.11, Time:8.14, D_real:0.21, D_fake:0.92, C_real:6.70, G_D_fake:1.44, G_C_fake:6.85,
# Iter:  303, Data:9.26, Time:10.30, D_real:0.52, D_fake:0.47, C_real:6.76, G_D_fake:1.81, G_C_fake:6.85,
# Iter:  304, Data:16.71, Time:17.86, D_real:0.66, D_fake:0.32, C_real:6.74, G_D_fake:1.59, G_C_fake:6.83,
# Iter:  305, Data:5.00, Time:6.03, D_real:0.61, D_fake:0.53, C_real:6.77, G_D_fake:1.54, G_C_fake:6.85,
# Iter:  306, Data:5.94, Time:6.98, D_real:0.66, D_fake:0.51, C_real:6.79, G_D_fake:1.72, G_C_fake:6.86,
# Iter:  307, Data:16.11, Time:17.15, D_real:0.66, D_fake:0.42, C_real:6.77, G_D_fake:1.34, G_C_fake:6.85,
# Iter:  308, Data:10.10, Time:11.36, D_real:0.44, D_fake:0.77, C_real:6.74, G_D_fake:1.40, G_C_fake:6.83,
# Iter:  309, Data:3.91, Time:4.94, D_real:0.52, D_fake:0.77, C_real:6.77, G_D_fake:1.76, G_C_fake:6.85,
# Iter:  310, Data:9.26, Time:10.29, D_real:0.72, D_fake:0.40, C_real:6.77, G_D_fake:1.63, G_C_fake:6.83,
# Iter:  311, Data:9.59, Time:10.63, D_real:0.51, D_fake:0.37, C_real:6.75, G_D_fake:1.40, G_C_fake:6.87,
# Iter:  312, Data:9.36, Time:10.39, D_real:0.22, D_fake:0.54, C_real:6.79, G_D_fake:2.18, G_C_fake:6.86,
# Iter:  313, Data:4.05, Time:5.12, D_real:0.38, D_fake:0.53, C_real:6.71, G_D_fake:2.61, G_C_fake:6.92,
# Iter:  314, Data:16.14, Time:17.17, D_real:0.68, D_fake:1.11, C_real:6.73, G_D_fake:3.12, G_C_fake:6.87,
# Iter:  315, Data:18.24, Time:19.42, D_real:1.70, D_fake:0.29, C_real:6.86, G_D_fake:1.47, G_C_fake:6.84,
# Iter:  316, Data:10.33, Time:11.37, D_real:0.65, D_fake:0.48, C_real:6.72, G_D_fake:1.43, G_C_fake:6.88,
# Iter:  317, Data:10.61, Time:11.64, D_real:0.42, D_fake:0.46, C_real:6.76, G_D_fake:2.20, G_C_fake:6.87,
# Iter:  318, Data:16.46, Time:17.65, D_real:0.42, D_fake:0.43, C_real:6.74, G_D_fake:2.44, G_C_fake:6.84,
# Iter:  319, Data:10.23, Time:11.27, D_real:0.53, D_fake:0.65, C_real:6.73, G_D_fake:2.01, G_C_fake:6.86,
# Iter:  320, Data:13.08, Time:14.12, D_real:0.69, D_fake:0.81, C_real:6.75, G_D_fake:1.56, G_C_fake:6.85,
# Iter:  321, Data:9.64, Time:10.68, D_real:0.80, D_fake:0.57, C_real:6.80, G_D_fake:1.12, G_C_fake:6.82,
# Iter:  322, Data:14.74, Time:15.95, D_real:0.28, D_fake:0.52, C_real:6.77, G_D_fake:0.87, G_C_fake:6.84,
# Iter:  323, Data:4.80, Time:5.83, D_real:0.15, D_fake:0.60, C_real:6.77, G_D_fake:1.60, G_C_fake:6.84,
# Iter:  324, Data:6.40, Time:7.43, D_real:0.19, D_fake:0.29, C_real:6.83, G_D_fake:2.00, G_C_fake:6.84,
# Iter:  325, Data:8.29, Time:9.33, D_real:0.32, D_fake:0.19, C_real:6.74, G_D_fake:2.01, G_C_fake:6.84,
# Iter:  326, Data:46.37, Time:47.51, D_real:0.20, D_fake:0.21, C_real:6.77, G_D_fake:1.86, G_C_fake:6.84,
# Iter:  327, Data:4.08, Time:5.12, D_real:0.22, D_fake:0.39, C_real:6.73, G_D_fake:1.89, G_C_fake:6.88,
# Iter:  328, Data:12.49, Time:13.52, D_real:0.28, D_fake:0.82, C_real:6.74, G_D_fake:2.26, G_C_fake:6.87,
# Iter:  329, Data:13.45, Time:14.69, D_real:0.78, D_fake:0.40, C_real:6.77, G_D_fake:1.67, G_C_fake:6.86,
# Iter:  330, Data:0.02, Time:1.20, D_real:0.63, D_fake:0.64, C_real:6.77, G_D_fake:1.58, G_C_fake:6.85,
# Iter:  331, Data:0.85, Time:1.89, D_real:0.61, D_fake:0.34, C_real:6.80, G_D_fake:1.52, G_C_fake:6.83,
# Iter:  332, Data:7.60, Time:8.64, D_real:0.40, D_fake:0.43, C_real:6.79, G_D_fake:1.69, G_C_fake:6.85,
# Iter:  333, Data:24.27, Time:25.30, D_real:0.36, D_fake:0.57, C_real:6.82, G_D_fake:2.13, G_C_fake:6.90,
# Iter:  334, Data:21.94, Time:23.20, D_real:0.57, D_fake:0.48, C_real:6.79, G_D_fake:1.48, G_C_fake:6.83,
# Iter:  335, Data:31.36, Time:32.38, D_real:0.54, D_fake:0.80, C_real:6.77, G_D_fake:1.43, G_C_fake:6.85,
# Iter:  336, Data:0.06, Time:1.30, D_real:0.71, D_fake:0.78, C_real:6.75, G_D_fake:1.48, G_C_fake:6.81,
# Iter:  337, Data:41.85, Time:43.09, D_real:0.70, D_fake:0.50, C_real:6.75, G_D_fake:1.32, G_C_fake:6.85,
# Iter:  338, Data:3.67, Time:4.70, D_real:0.47, D_fake:0.60, C_real:6.76, G_D_fake:1.79, G_C_fake:6.83,
# Iter:  339, Data:3.85, Time:4.89, D_real:0.60, D_fake:0.49, C_real:6.76, G_D_fake:1.83, G_C_fake:6.85,
# Iter:  340, Data:14.98, Time:16.02, D_real:0.67, D_fake:0.62, C_real:6.77, G_D_fake:2.01, G_C_fake:6.86,
# Iter:  341, Data:14.66, Time:15.77, D_real:0.93, D_fake:0.33, C_real:6.77, G_D_fake:1.15, G_C_fake:6.87,
# Iter:  342, Data:21.42, Time:22.45, D_real:0.51, D_fake:0.60, C_real:6.78, G_D_fake:1.66, G_C_fake:6.85,
# Iter:  343, Data:10.44, Time:11.48, D_real:0.61, D_fake:0.39, C_real:6.79, G_D_fake:1.58, G_C_fake:6.86,
# Iter:  344, Data:21.92, Time:23.05, D_real:0.53, D_fake:0.50, C_real:6.79, G_D_fake:1.42, G_C_fake:6.87,
# Iter:  345, Data:36.53, Time:37.64, D_real:0.53, D_fake:0.57, C_real:6.75, G_D_fake:1.48, G_C_fake:6.84,
# Iter:  346, Data:4.33, Time:5.36, D_real:0.60, D_fake:0.52, C_real:6.82, G_D_fake:1.25, G_C_fake:6.85,
# Iter:  347, Data:6.70, Time:7.74, D_real:0.60, D_fake:0.55, C_real:6.76, G_D_fake:0.98, G_C_fake:6.84,
# Iter:  348, Data:20.42, Time:21.45, D_real:0.44, D_fake:0.75, C_real:6.73, G_D_fake:1.57, G_C_fake:6.80,
# Iter:  349, Data:13.32, Time:14.51, D_real:0.75, D_fake:0.39, C_real:6.76, G_D_fake:0.94, G_C_fake:6.83,
# Iter:  350, Data:6.82, Time:7.85, D_real:0.40, D_fake:0.75, C_real:6.73, G_D_fake:1.53, G_C_fake:6.87,
# Iter:  351, Data:5.43, Time:6.47, D_real:0.66, D_fake:0.48, C_real:6.74, G_D_fake:1.29, G_C_fake:6.88,
# Iter:  352, Data:16.11, Time:17.15, D_real:0.60, D_fake:0.63, C_real:6.75, G_D_fake:1.18, G_C_fake:6.86,
# Iter:  353, Data:15.00, Time:16.21, D_real:0.55, D_fake:0.63, C_real:6.79, G_D_fake:1.30, G_C_fake:6.84,
# Iter:  354, Data:3.21, Time:4.24, D_real:0.64, D_fake:0.51, C_real:6.75, G_D_fake:1.16, G_C_fake:6.87,
# Iter:  355, Data:78.78, Time:79.99, D_real:0.48, D_fake:0.58, C_real:6.75, G_D_fake:1.32, G_C_fake:6.85,
# Iter:  356, Data:6.58, Time:7.76, D_real:0.51, D_fake:0.48, C_real:6.74, G_D_fake:1.31, G_C_fake:6.84,
# Iter:  357, Data:13.60, Time:14.63, D_real:0.44, D_fake:0.52, C_real:6.74, G_D_fake:1.60, G_C_fake:6.88,
# Iter:  358, Data:4.07, Time:5.10, D_real:0.47, D_fake:0.44, C_real:6.72, G_D_fake:1.53, G_C_fake:6.84,
# Iter:  359, Data:21.85, Time:23.05, D_real:0.44, D_fake:0.42, C_real:6.73, G_D_fake:1.50, G_C_fake:6.86,
# Iter:  360, Data:4.44, Time:5.47, D_real:0.45, D_fake:0.41, C_real:6.69, G_D_fake:1.45, G_C_fake:6.85,
# Iter:  361, Data:11.69, Time:12.73, D_real:0.37, D_fake:0.47, C_real:6.70, G_D_fake:1.62, G_C_fake:6.90,
# Iter:  362, Data:4.34, Time:5.38, D_real:0.45, D_fake:0.42, C_real:6.74, G_D_fake:1.54, G_C_fake:6.86,
# Iter:  363, Data:5.54, Time:6.57, D_real:0.38, D_fake:0.54, C_real:6.73, G_D_fake:2.10, G_C_fake:6.91,
# Iter:  364, Data:22.69, Time:23.85, D_real:0.68, D_fake:0.32, C_real:6.75, G_D_fake:0.91, G_C_fake:6.83,
# Iter:  365, Data:3.23, Time:4.26, D_real:0.28, D_fake:1.04, C_real:6.75, G_D_fake:3.41, G_C_fake:6.92,
# Iter:  366, Data:46.58, Time:47.70, D_real:1.87, D_fake:0.10, C_real:6.78, G_D_fake:0.40, G_C_fake:6.84,
# Iter:  367, Data:5.09, Time:6.13, D_real:0.13, D_fake:1.72, C_real:6.66, G_D_fake:0.95, G_C_fake:6.83,
# Iter:  368, Data:4.34, Time:5.38, D_real:0.29, D_fake:0.72, C_real:6.79, G_D_fake:1.53, G_C_fake:6.86,
# Iter:  369, Data:21.31, Time:22.50, D_real:0.58, D_fake:0.46, C_real:6.74, G_D_fake:1.70, G_C_fake:6.84,
# Iter:  370, Data:5.72, Time:6.76, D_real:0.70, D_fake:0.39, C_real:6.77, G_D_fake:1.47, G_C_fake:6.88,
# Iter:  371, Data:3.68, Time:4.73, D_real:0.61, D_fake:0.46, C_real:6.76, G_D_fake:1.48, G_C_fake:6.85,
# Iter:  372, Data:4.74, Time:5.77, D_real:0.55, D_fake:0.39, C_real:6.75, G_D_fake:1.56, G_C_fake:6.87,
# Iter:  373, Data:3.96, Time:4.99, D_real:0.39, D_fake:0.42, C_real:6.76, G_D_fake:1.55, G_C_fake:6.84,
# Iter:  374, Data:4.74, Time:5.78, D_real:0.38, D_fake:0.64, C_real:6.79, G_D_fake:1.76, G_C_fake:6.89,
# Iter:  375, Data:3.94, Time:4.97, D_real:0.54, D_fake:0.60, C_real:6.69, G_D_fake:1.77, G_C_fake:6.84,
# Iter:  376, Data:10.03, Time:11.20, D_real:0.72, D_fake:0.52, C_real:6.71, G_D_fake:1.54, G_C_fake:6.85,
# Iter:  377, Data:4.02, Time:5.05, D_real:0.63, D_fake:0.50, C_real:6.72, G_D_fake:1.32, G_C_fake:6.84,
# Iter:  378, Data:3.52, Time:4.56, D_real:0.34, D_fake:0.54, C_real:6.73, G_D_fake:1.35, G_C_fake:6.82,
# Iter:  379, Data:4.01, Time:5.04, D_real:0.36, D_fake:0.54, C_real:6.74, G_D_fake:1.52, G_C_fake:6.83,
# Iter:  380, Data:15.93, Time:16.96, D_real:0.35, D_fake:0.72, C_real:6.79, G_D_fake:1.76, G_C_fake:6.83,
# Iter:  381, Data:10.17, Time:11.39, D_real:0.56, D_fake:0.47, C_real:6.73, G_D_fake:1.67, G_C_fake:6.82,
# Iter:  382, Data:17.59, Time:18.62, D_real:0.70, D_fake:0.54, C_real:6.78, G_D_fake:1.37, G_C_fake:6.85,
# Iter:  383, Data:5.41, Time:6.45, D_real:0.61, D_fake:0.47, C_real:6.80, G_D_fake:1.31, G_C_fake:6.84,
# Iter:  384, Data:47.28, Time:48.40, D_real:0.43, D_fake:0.48, C_real:6.76, G_D_fake:1.44, G_C_fake:6.85,
# Iter:  385, Data:6.96, Time:8.12, D_real:0.32, D_fake:0.50, C_real:6.69, G_D_fake:1.76, G_C_fake:6.91,
# Iter:  386, Data:7.99, Time:9.02, D_real:0.36, D_fake:0.46, C_real:6.71, G_D_fake:1.88, G_C_fake:6.84,
# Iter:  387, Data:8.21, Time:9.24, D_real:0.33, D_fake:0.58, C_real:6.74, G_D_fake:2.49, G_C_fake:6.91,
# Iter:  388, Data:4.87, Time:5.91, D_real:0.65, D_fake:0.53, C_real:6.77, G_D_fake:1.64, G_C_fake:6.85,
# Iter:  389, Data:6.39, Time:7.43, D_real:0.61, D_fake:0.81, C_real:6.80, G_D_fake:1.38, G_C_fake:6.86,
# Iter:  390, Data:7.89, Time:9.05, D_real:0.78, D_fake:0.62, C_real:6.73, G_D_fake:1.31, G_C_fake:6.85,
# Iter:  391, Data:45.52, Time:46.67, D_real:0.54, D_fake:0.49, C_real:6.74, G_D_fake:1.51, G_C_fake:6.88,
# Iter:  392, Data:16.89, Time:17.93, D_real:0.36, D_fake:0.50, C_real:6.67, G_D_fake:1.78, G_C_fake:6.83,
# Iter:  393, Data:5.66, Time:6.70, D_real:0.38, D_fake:0.48, C_real:6.77, G_D_fake:2.20, G_C_fake:6.92,
# Iter:  394, Data:4.53, Time:5.57, D_real:0.63, D_fake:0.52, C_real:6.77, G_D_fake:1.80, G_C_fake:6.91,
# Iter:  395, Data:22.84, Time:24.01, D_real:0.77, D_fake:0.60, C_real:6.70, G_D_fake:1.69, G_C_fake:6.89,
# Iter:  396, Data:8.32, Time:9.35, D_real:0.83, D_fake:0.57, C_real:6.73, G_D_fake:1.51, G_C_fake:6.85,
# Iter:  397, Data:3.75, Time:4.79, D_real:0.52, D_fake:0.48, C_real:6.77, G_D_fake:1.73, G_C_fake:6.90,
# Iter:  398, Data:6.94, Time:7.97, D_real:0.40, D_fake:0.62, C_real:6.74, G_D_fake:2.88, G_C_fake:6.85,
# Iter:  399, Data:12.99, Time:14.11, D_real:0.90, D_fake:0.15, C_real:6.76, G_D_fake:1.35, G_C_fake:6.87,
# Iter:  400, Data:5.32, Time:6.35, D_real:0.34, D_fake:0.81, C_real:6.80, G_D_fake:1.36, G_C_fake:6.83,
# Iter:  401, Data:15.92, Time:16.96, D_real:0.46, D_fake:0.79, C_real:6.81, G_D_fake:1.71, G_C_fake:6.85,
# Iter:  402, Data:11.44, Time:12.56, D_real:1.06, D_fake:0.44, C_real:6.83, G_D_fake:1.01, G_C_fake:6.85,
# Iter:  403, Data:8.39, Time:9.43, D_real:0.67, D_fake:0.74, C_real:6.77, G_D_fake:1.01, G_C_fake:6.85,
# Iter:  404, Data:6.93, Time:7.96, D_real:0.68, D_fake:0.61, C_real:6.76, G_D_fake:1.19, G_C_fake:6.87,
# Iter:  405, Data:17.03, Time:18.06, D_real:0.55, D_fake:0.46, C_real:6.74, G_D_fake:1.25, G_C_fake:6.86,
# Iter:  406, Data:6.05, Time:7.25, D_real:0.44, D_fake:0.50, C_real:6.79, G_D_fake:1.38, G_C_fake:6.84,
# Iter:  407, Data:3.37, Time:4.40, D_real:0.43, D_fake:0.56, C_real:6.77, G_D_fake:1.55, G_C_fake:6.84,
# Iter:  408, Data:14.43, Time:15.47, D_real:0.57, D_fake:0.51, C_real:6.77, G_D_fake:1.54, G_C_fake:6.83,
# Iter:  409, Data:4.48, Time:5.52, D_real:0.55, D_fake:0.38, C_real:6.72, G_D_fake:1.24, G_C_fake:6.84,
# Iter:  410, Data:4.54, Time:5.58, D_real:0.31, D_fake:0.56, C_real:6.78, G_D_fake:1.27, G_C_fake:6.86,
# Iter:  411, Data:12.49, Time:13.70, D_real:0.27, D_fake:0.73, C_real:6.80, G_D_fake:2.09, G_C_fake:6.86,
# Iter:  412, Data:12.93, Time:13.97, D_real:0.82, D_fake:0.32, C_real:6.77, G_D_fake:1.45, G_C_fake:6.83,
# Iter:  413, Data:9.18, Time:10.22, D_real:0.72, D_fake:0.72, C_real:6.78, G_D_fake:1.48, G_C_fake:6.81,
# Iter:  414, Data:3.79, Time:4.82, D_real:0.78, D_fake:0.48, C_real:6.75, G_D_fake:1.35, G_C_fake:6.85,
# Iter:  415, Data:6.15, Time:7.29, D_real:0.58, D_fake:0.56, C_real:6.77, G_D_fake:1.43, G_C_fake:6.84,
# Iter:  416, Data:17.94, Time:18.97, D_real:0.55, D_fake:0.53, C_real:6.75, G_D_fake:1.58, G_C_fake:6.84,
# Iter:  417, Data:14.32, Time:15.35, D_real:0.60, D_fake:0.44, C_real:6.74, G_D_fake:1.21, G_C_fake:6.84,
# Iter:  418, Data:12.99, Time:14.14, D_real:0.40, D_fake:0.60, C_real:6.79, G_D_fake:1.47, G_C_fake:6.82,
# Iter:  419, Data:7.04, Time:8.08, D_real:0.48, D_fake:0.47, C_real:6.72, G_D_fake:1.77, G_C_fake:6.86,
# Iter:  420, Data:16.55, Time:17.58, D_real:0.56, D_fake:0.37, C_real:6.71, G_D_fake:1.31, G_C_fake:6.91,
# Iter:  421, Data:10.77, Time:11.80, D_real:0.36, D_fake:0.57, C_real:6.73, G_D_fake:1.96, G_C_fake:6.89,
# Iter:  422, Data:5.62, Time:6.76, D_real:0.60, D_fake:0.35, C_real:6.70, G_D_fake:1.26, G_C_fake:6.88,
# Iter:  423, Data:22.10, Time:23.13, D_real:0.34, D_fake:0.78, C_real:6.82, G_D_fake:2.34, G_C_fake:6.90,
# Iter:  424, Data:7.88, Time:8.92, D_real:0.88, D_fake:0.28, C_real:6.74, G_D_fake:0.73, G_C_fake:6.89,
# Iter:  425, Data:4.49, Time:5.53, D_real:0.14, D_fake:1.52, C_real:6.70, G_D_fake:2.28, G_C_fake:6.90,
# Iter:  426, Data:3.82, Time:4.97, D_real:1.35, D_fake:0.30, C_real:6.76, G_D_fake:0.72, G_C_fake:6.90,
# Iter:  427, Data:12.18, Time:13.22, D_real:0.63, D_fake:1.49, C_real:6.77, G_D_fake:2.20, G_C_fake:6.88,
# Iter:  428, Data:5.58, Time:6.62, D_real:1.20, D_fake:0.20, C_real:6.75, G_D_fake:1.72, G_C_fake:6.86,
# Iter:  429, Data:6.94, Time:7.97, D_real:0.56, D_fake:0.30, C_real:6.73, G_D_fake:1.25, G_C_fake:6.85,
# Iter:  430, Data:8.76, Time:9.80, D_real:0.26, D_fake:0.57, C_real:6.63, G_D_fake:1.06, G_C_fake:6.84,
# Iter:  431, Data:8.34, Time:9.55, D_real:0.17, D_fake:0.88, C_real:6.72, G_D_fake:1.44, G_C_fake:6.83,
# Iter:  432, Data:19.82, Time:20.85, D_real:0.37, D_fake:0.49, C_real:6.73, G_D_fake:1.80, G_C_fake:6.88,
# Iter:  433, Data:31.02, Time:32.21, D_real:0.53, D_fake:0.45, C_real:6.71, G_D_fake:1.52, G_C_fake:6.83,
# Iter:  434, Data:4.18, Time:5.22, D_real:0.58, D_fake:0.99, C_real:6.72, G_D_fake:1.74, G_C_fake:6.83,
# Iter:  435, Data:6.46, Time:7.50, D_real:0.93, D_fake:0.55, C_real:6.76, G_D_fake:1.24, G_C_fake:6.86,
# Iter:  436, Data:9.41, Time:10.44, D_real:0.59, D_fake:0.63, C_real:6.82, G_D_fake:1.29, G_C_fake:6.84,
# Iter:  437, Data:12.19, Time:13.31, D_real:0.40, D_fake:0.47, C_real:6.72, G_D_fake:1.69, G_C_fake:6.94,
# Iter:  438, Data:3.98, Time:5.02, D_real:0.37, D_fake:0.37, C_real:6.70, G_D_fake:2.03, G_C_fake:6.86,
# Iter:  439, Data:4.03, Time:5.07, D_real:0.39, D_fake:0.37, C_real:6.69, G_D_fake:2.05, G_C_fake:6.89,
# Iter:  440, Data:19.40, Time:20.43, D_real:0.31, D_fake:0.61, C_real:6.70, G_D_fake:2.81, G_C_fake:6.87,
# Iter:  441, Data:8.76, Time:9.92, D_real:1.07, D_fake:0.34, C_real:6.72, G_D_fake:0.45, G_C_fake:6.87,
# Iter:  442, Data:8.91, Time:9.94, D_real:0.27, D_fake:1.79, C_real:6.71, G_D_fake:2.49, G_C_fake:6.86,
# Iter:  443, Data:9.34, Time:10.37, D_real:1.78, D_fake:0.17, C_real:6.73, G_D_fake:0.99, G_C_fake:6.89,
# Iter:  444, Data:31.67, Time:32.85, D_real:0.62, D_fake:0.64, C_real:6.66, G_D_fake:0.70, G_C_fake:6.88,
# Iter:  445, Data:6.40, Time:7.44, D_real:0.44, D_fake:0.87, C_real:6.74, G_D_fake:0.89, G_C_fake:6.88,
# Iter:  446, Data:7.19, Time:8.22, D_real:0.43, D_fake:0.71, C_real:6.68, G_D_fake:1.19, G_C_fake:6.84,
# Iter:  447, Data:12.71, Time:13.75, D_real:0.53, D_fake:0.44, C_real:6.66, G_D_fake:1.39, G_C_fake:6.85,
# Iter:  448, Data:3.86, Time:4.98, D_real:0.50, D_fake:0.42, C_real:6.75, G_D_fake:1.31, G_C_fake:6.88,
# Iter:  449, Data:17.65, Time:18.68, D_real:0.48, D_fake:0.52, C_real:6.74, G_D_fake:1.22, G_C_fake:6.83,
# Iter:  450, Data:4.16, Time:5.19, D_real:0.52, D_fake:0.62, C_real:6.65, G_D_fake:1.24, G_C_fake:6.89,
# Iter:  451, Data:3.61, Time:4.65, D_real:0.56, D_fake:0.69, C_real:6.71, G_D_fake:1.33, G_C_fake:6.86,
# Iter:  452, Data:21.07, Time:22.28, D_real:0.70, D_fake:0.58, C_real:6.69, G_D_fake:1.24, G_C_fake:6.88,
# Iter:  453, Data:4.39, Time:5.43, D_real:0.66, D_fake:0.77, C_real:6.65, G_D_fake:1.15, G_C_fake:6.85,
# Iter:  454, Data:11.97, Time:12.99, D_real:0.59, D_fake:0.66, C_real:6.68, G_D_fake:1.42, G_C_fake:6.91,
# Iter:  455, Data:10.42, Time:11.45, D_real:0.73, D_fake:0.64, C_real:6.64, G_D_fake:1.34, G_C_fake:6.85,
# Iter:  456, Data:3.83, Time:4.86, D_real:0.67, D_fake:0.57, C_real:6.65, G_D_fake:1.41, G_C_fake:6.84,
# Iter:  457, Data:4.15, Time:5.26, D_real:0.74, D_fake:0.58, C_real:6.63, G_D_fake:1.46, G_C_fake:6.77,
# Iter:  458, Data:17.49, Time:18.52, D_real:0.69, D_fake:0.43, C_real:6.78, G_D_fake:1.55, G_C_fake:6.83,
# Iter:  459, Data:14.09, Time:15.13, D_real:0.53, D_fake:0.52, C_real:6.64, G_D_fake:1.43, G_C_fake:6.87,
# Iter:  460, Data:6.84, Time:7.95, D_real:0.44, D_fake:0.54, C_real:6.66, G_D_fake:1.51, G_C_fake:6.95,
# Iter:  461, Data:9.92, Time:10.96, D_real:0.46, D_fake:0.58, C_real:6.69, G_D_fake:1.56, G_C_fake:6.86,
# ...
# Iter:  846, Data:8.50, Time:9.54, D_real:0.40, D_fake:0.30, C_real:6.11, G_D_fake:2.89, G_C_fake:6.78,
# Iter:  847, Data:3.33, Time:4.37, D_real:0.38, D_fake:0.42, C_real:6.16, G_D_fake:2.74, G_C_fake:6.67,
# Iter:  848, Data:19.35, Time:20.51, D_real:0.64, D_fake:0.44, C_real:6.26, G_D_fake:2.24, G_C_fake:6.71,
# Iter:  849, Data:8.58, Time:9.62, D_real:0.75, D_fake:0.63, C_real:6.17, G_D_fake:1.97, G_C_fake:6.71,
# Iter:  850, Data:4.35, Time:5.39, D_real:0.69, D_fake:0.59, C_real:6.30, G_D_fake:2.24, G_C_fake:6.71,
# Iter:  851, Data:5.06, Time:6.10, D_real:0.64, D_fake:0.40, C_real:6.06, G_D_fake:2.01, G_C_fake:6.65,
# Iter:  852, Data:14.86, Time:16.05, D_real:0.32, D_fake:0.50, C_real:6.19, G_D_fake:2.79, G_C_fake:6.67,
# Iter:  853, Data:4.05, Time:5.10, D_real:0.44, D_fake:0.28, C_real:6.20, G_D_fake:2.32, G_C_fake:6.81,
# Iter:  854, Data:8.75, Time:9.79, D_real:0.38, D_fake:0.42, C_real:6.24, G_D_fake:2.16, G_C_fake:6.73,
# Iter:  855, Data:19.92, Time:20.95, D_real:0.35, D_fake:0.51, C_real:6.17, G_D_fake:2.47, G_C_fake:6.67,
# Iter:  856, Data:26.63, Time:27.87, D_real:0.57, D_fake:0.38, C_real:6.05, G_D_fake:1.79, G_C_fake:6.73,
# Iter:  857, Data:5.01, Time:6.05, D_real:0.38, D_fake:0.85, C_real:6.05, G_D_fake:2.76, G_C_fake:6.69,
# Iter:  858, Data:5.02, Time:6.05, D_real:0.76, D_fake:0.29, C_real:6.25, G_D_fake:1.83, G_C_fake:6.57,
# Iter:  859, Data:5.72, Time:6.76, D_real:0.42, D_fake:0.73, C_real:6.28, G_D_fake:2.24, G_C_fake:6.57,
# Iter:  860, Data:21.50, Time:22.74, D_real:0.49, D_fake:0.60, C_real:6.09, G_D_fake:3.16, G_C_fake:6.78,
# Iter:  861, Data:8.04, Time:9.07, D_real:0.74, D_fake:0.37, C_real:6.13, G_D_fake:2.37, G_C_fake:6.81,
# Iter:  862, Data:7.57, Time:8.61, D_real:0.39, D_fake:0.67, C_real:6.07, G_D_fake:3.49, G_C_fake:6.71,
# Iter:  863, Data:3.73, Time:4.77, D_real:0.53, D_fake:0.27, C_real:6.04, G_D_fake:2.81, G_C_fake:6.59,
# Iter:  864, Data:13.95, Time:15.16, D_real:0.23, D_fake:0.67, C_real:6.17, G_D_fake:4.27, G_C_fake:6.81,
# Iter:  865, Data:3.37, Time:4.41, D_real:0.77, D_fake:0.20, C_real:6.11, G_D_fake:2.09, G_C_fake:6.70,
# Iter:  866, Data:11.98, Time:13.02, D_real:0.27, D_fake:1.67, C_real:6.11, G_D_fake:5.95, G_C_fake:6.90,
# Iter:  867, Data:3.85, Time:4.89, D_real:2.85, D_fake:0.02, C_real:6.32, G_D_fake:1.22, G_C_fake:6.72,
# Iter:  868, Data:4.66, Time:5.70, D_real:0.27, D_fake:0.86, C_real:6.23, G_D_fake:1.46, G_C_fake:6.73,
# Iter:  869, Data:4.88, Time:5.92, D_real:0.19, D_fake:0.67, C_real:6.12, G_D_fake:2.80, G_C_fake:6.77,
# Iter:  870, Data:9.63, Time:10.85, D_real:0.47, D_fake:0.22, C_real:6.14, G_D_fake:2.70, G_C_fake:6.74,
# Iter:  871, Data:23.33, Time:24.37, D_real:0.39, D_fake:0.27, C_real:6.11, G_D_fake:2.35, G_C_fake:6.79,
# Iter:  872, Data:18.94, Time:20.14, D_real:0.34, D_fake:0.55, C_real:6.21, G_D_fake:2.63, G_C_fake:6.90,
# Iter:  873, Data:9.66, Time:10.70, D_real:0.48, D_fake:0.45, C_real:6.09, G_D_fake:2.85, G_C_fake:7.06,
# Iter:  874, Data:8.96, Time:9.99, D_real:0.54, D_fake:0.33, C_real:6.12, G_D_fake:2.45, G_C_fake:6.92,
# Iter:  875, Data:5.94, Time:6.97, D_real:0.38, D_fake:0.50, C_real:6.10, G_D_fake:2.67, G_C_fake:6.66,
# Iter:  876, Data:18.81, Time:20.06, D_real:0.50, D_fake:0.34, C_real:6.18, G_D_fake:2.60, G_C_fake:6.59,
# Iter:  877, Data:7.47, Time:8.51, D_real:0.45, D_fake:0.40, C_real:6.13, G_D_fake:2.47, G_C_fake:6.60,
# Iter:  878, Data:8.67, Time:9.71, D_real:0.41, D_fake:0.49, C_real:6.06, G_D_fake:2.61, G_C_fake:6.70,
# Iter:  879, Data:3.92, Time:4.96, D_real:0.58, D_fake:0.55, C_real:6.17, G_D_fake:2.37, G_C_fake:6.78,
# Iter:  880, Data:3.63, Time:4.67, D_real:0.58, D_fake:0.82, C_real:6.21, G_D_fake:2.41, G_C_fake:6.67,
# Iter:  881, Data:3.43, Time:4.47, D_real:0.76, D_fake:0.58, C_real:6.16, G_D_fake:1.76, G_C_fake:6.72,
# Iter:  882, Data:14.25, Time:15.47, D_real:0.63, D_fake:0.75, C_real:6.00, G_D_fake:1.63, G_C_fake:6.72,
# Iter:  883, Data:7.61, Time:8.64, D_real:0.50, D_fake:0.77, C_real:6.18, G_D_fake:2.30, G_C_fake:6.69,
# Iter:  884, Data:3.76, Time:4.80, D_real:0.58, D_fake:0.47, C_real:6.25, G_D_fake:2.40, G_C_fake:6.82,
# Iter:  885, Data:10.71, Time:11.74, D_real:0.47, D_fake:0.48, C_real:6.03, G_D_fake:2.57, G_C_fake:6.77,
# Iter:  886, Data:15.54, Time:16.58, D_real:0.53, D_fake:0.59, C_real:6.15, G_D_fake:3.62, G_C_fake:6.91,
# Iter:  887, Data:20.93, Time:22.11, D_real:0.64, D_fake:0.28, C_real:6.08, G_D_fake:2.31, G_C_fake:6.88,
# Iter:  888, Data:22.48, Time:23.52, D_real:0.31, D_fake:0.77, C_real:6.00, G_D_fake:4.59, G_C_fake:6.75,
# Iter:  889, Data:3.97, Time:5.01, D_real:1.11, D_fake:0.14, C_real:6.15, G_D_fake:0.92, G_C_fake:6.80,
# Iter:  890, Data:7.29, Time:8.48, D_real:0.14, D_fake:1.65, C_real:6.20, G_D_fake:3.72, G_C_fake:6.73,
# Iter:  891, Data:11.73, Time:12.76, D_real:0.88, D_fake:0.12, C_real:6.28, G_D_fake:2.50, G_C_fake:6.60,
# Iter:  892, Data:2.74, Time:3.77, D_real:0.38, D_fake:0.46, C_real:6.07, G_D_fake:1.94, G_C_fake:6.68,
# Iter:  893, Data:3.24, Time:4.27, D_real:0.33, D_fake:0.75, C_real:6.00, G_D_fake:2.46, G_C_fake:6.72,
# Iter:  894, Data:3.39, Time:4.42, D_real:0.58, D_fake:0.32, C_real:6.04, G_D_fake:2.16, G_C_fake:6.73,
# Iter:  895, Data:8.75, Time:9.78, D_real:0.41, D_fake:0.59, C_real:6.21, G_D_fake:1.99, G_C_fake:6.61,
# Iter:  896, Data:3.01, Time:4.20, D_real:0.40, D_fake:0.81, C_real:5.99, G_D_fake:2.53, G_C_fake:6.65,
# Iter:  897, Data:6.97, Time:8.01, D_real:0.69, D_fake:0.41, C_real:6.14, G_D_fake:2.33, G_C_fake:6.72,
# Iter:  898, Data:4.19, Time:5.24, D_real:0.70, D_fake:0.42, C_real:6.10, G_D_fake:2.14, G_C_fake:6.65,
# Iter:  899, Data:3.08, Time:4.11, D_real:0.44, D_fake:0.52, C_real:6.13, G_D_fake:2.73, G_C_fake:6.81,
# Iter:  900, Data:6.40, Time:7.43, D_real:0.56, D_fake:0.37, C_real:5.99, G_D_fake:2.65, G_C_fake:6.70,
# Iter:  901, Data:3.56, Time:4.60, D_real:0.36, D_fake:0.48, C_real:5.95, G_D_fake:2.76, G_C_fake:6.65,
# Iter:  902, Data:12.01, Time:13.16, D_real:0.56, D_fake:0.46, C_real:6.03, G_D_fake:2.53, G_C_fake:6.80,
# Iter:  903, Data:6.35, Time:7.39, D_real:0.57, D_fake:0.52, C_real:6.07, G_D_fake:2.45, G_C_fake:6.69,
# Iter:  904, Data:13.43, Time:14.46, D_real:0.75, D_fake:0.60, C_real:6.34, G_D_fake:2.13, G_C_fake:6.66,
# Iter:  905, Data:22.06, Time:23.22, D_real:0.65, D_fake:0.67, C_real:5.99, G_D_fake:2.07, G_C_fake:6.79,
# Iter:  906, Data:3.40, Time:4.44, D_real:0.69, D_fake:0.79, C_real:6.07, G_D_fake:2.33, G_C_fake:6.84,
# Iter:  907, Data:7.13, Time:8.16, D_real:0.81, D_fake:0.51, C_real:6.08, G_D_fake:2.12, G_C_fake:6.72,
# Iter:  908, Data:4.50, Time:5.54, D_real:0.47, D_fake:0.53, C_real:5.93, G_D_fake:2.58, G_C_fake:6.92,
# Iter:  909, Data:12.35, Time:13.39, D_real:0.50, D_fake:0.48, C_real:5.93, G_D_fake:2.76, G_C_fake:6.78,
# Iter:  910, Data:7.12, Time:8.16, D_real:0.74, D_fake:0.47, C_real:6.08, G_D_fake:1.99, G_C_fake:6.61,
# Iter:  911, Data:3.48, Time:4.64, D_real:0.44, D_fake:0.71, C_real:6.22, G_D_fake:3.30, G_C_fake:6.50,
# Iter:  912, Data:4.30, Time:5.34, D_real:0.84, D_fake:0.23, C_real:6.15, G_D_fake:2.28, G_C_fake:6.66,
# Iter:  913, Data:8.70, Time:9.73, D_real:0.34, D_fake:0.52, C_real:5.94, G_D_fake:2.75, G_C_fake:6.87,
# Iter:  914, Data:5.56, Time:6.60, D_real:0.30, D_fake:0.66, C_real:6.34, G_D_fake:3.57, G_C_fake:6.86,
# Iter:  915, Data:3.85, Time:4.88, D_real:0.92, D_fake:0.29, C_real:6.31, G_D_fake:1.93, G_C_fake:6.69,
# Iter:  916, Data:14.94, Time:16.06, D_real:0.49, D_fake:0.66, C_real:5.92, G_D_fake:1.65, G_C_fake:6.79,
# Iter:  917, Data:14.05, Time:15.09, D_real:0.42, D_fake:0.81, C_real:5.97, G_D_fake:2.32, G_C_fake:6.77,
# Iter:  918, Data:8.08, Time:9.12, D_real:0.96, D_fake:0.48, C_real:6.15, G_D_fake:1.49, G_C_fake:6.68,
# Iter:  919, Data:6.87, Time:7.90, D_real:0.58, D_fake:0.65, C_real:6.39, G_D_fake:1.49, G_C_fake:6.73,
# Iter:  920, Data:3.53, Time:4.57, D_real:0.47, D_fake:0.53, C_real:6.17, G_D_fake:1.58, G_C_fake:6.75,
# Iter:  921, Data:3.58, Time:4.72, D_real:0.37, D_fake:0.51, C_real:6.01, G_D_fake:1.98, G_C_fake:6.65,
# Iter:  922, Data:2.96, Time:4.00, D_real:0.35, D_fake:0.40, C_real:6.15, G_D_fake:2.16, G_C_fake:6.78,
# Iter:  923, Data:17.41, Time:18.44, D_real:0.26, D_fake:0.36, C_real:6.09, G_D_fake:2.54, G_C_fake:6.75,
# Iter:  924, Data:7.85, Time:8.89, D_real:0.39, D_fake:0.35, C_real:5.99, G_D_fake:2.39, G_C_fake:6.89,
# Iter:  925, Data:8.40, Time:9.56, D_real:0.49, D_fake:0.43, C_real:6.15, G_D_fake:2.24, G_C_fake:6.78,
# Iter:  926, Data:12.58, Time:13.62, D_real:0.50, D_fake:0.57, C_real:5.91, G_D_fake:2.72, G_C_fake:6.78,
# Iter:  927, Data:3.41, Time:4.44, D_real:0.89, D_fake:0.40, C_real:5.83, G_D_fake:1.67, G_C_fake:6.81,
# Iter:  928, Data:4.87, Time:5.91, D_real:0.43, D_fake:1.06, C_real:6.11, G_D_fake:3.85, G_C_fake:6.84,
# Iter:  929, Data:14.88, Time:15.92, D_real:1.64, D_fake:0.11, C_real:6.13, G_D_fake:1.16, G_C_fake:6.69,
# Iter:  930, Data:4.39, Time:5.54, D_real:0.31, D_fake:0.87, C_real:5.89, G_D_fake:1.91, G_C_fake:6.79,
# Iter:  931, Data:3.36, Time:4.40, D_real:0.27, D_fake:0.51, C_real:6.13, G_D_fake:3.07, G_C_fake:6.81,
# Iter:  932, Data:10.34, Time:11.38, D_real:0.55, D_fake:0.28, C_real:6.14, G_D_fake:2.52, G_C_fake:6.52,
# Iter:  933, Data:15.06, Time:16.10, D_real:0.46, D_fake:0.68, C_real:6.12, G_D_fake:2.77, G_C_fake:6.67,
# Iter:  934, Data:3.88, Time:4.92, D_real:0.83, D_fake:0.25, C_real:6.11, G_D_fake:1.71, G_C_fake:6.72,
# Iter:  935, Data:4.36, Time:5.48, D_real:0.36, D_fake:0.58, C_real:6.01, G_D_fake:1.60, G_C_fake:6.85,
# Iter:  936, Data:4.37, Time:5.40, D_real:0.34, D_fake:0.68, C_real:6.10, G_D_fake:2.16, G_C_fake:6.66,
# Iter:  937, Data:11.73, Time:12.77, D_real:0.53, D_fake:0.38, C_real:5.99, G_D_fake:2.14, G_C_fake:6.78,
# Iter:  938, Data:6.24, Time:7.28, D_real:0.38, D_fake:0.42, C_real:5.89, G_D_fake:2.09, G_C_fake:6.91,
# Iter:  939, Data:3.67, Time:4.70, D_real:0.46, D_fake:0.50, C_real:5.93, G_D_fake:2.31, G_C_fake:6.80,
# Iter:  940, Data:8.47, Time:9.52, D_real:0.59, D_fake:0.46, C_real:5.75, G_D_fake:2.10, G_C_fake:6.72,
# Iter:  941, Data:4.28, Time:5.42, D_real:0.53, D_fake:0.69, C_real:6.10, G_D_fake:2.99, G_C_fake:6.79,
# Iter:  942, Data:17.43, Time:18.46, D_real:0.81, D_fake:0.36, C_real:5.84, G_D_fake:1.70, G_C_fake:6.63,
# Iter:  943, Data:38.12, Time:39.31, D_real:0.28, D_fake:1.08, C_real:5.99, G_D_fake:4.05, G_C_fake:6.56,
# Iter:  944, Data:4.10, Time:5.14, D_real:1.18, D_fake:0.13, C_real:6.13, G_D_fake:1.61, G_C_fake:6.82,
# Iter:  945, Data:3.58, Time:4.62, D_real:0.29, D_fake:1.02, C_real:5.91, G_D_fake:2.60, G_C_fake:6.75,
# Iter:  946, Data:7.80, Time:8.84, D_real:0.35, D_fake:0.46, C_real:6.03, G_D_fake:3.21, G_C_fake:6.64,
# Iter:  947, Data:15.70, Time:16.74, D_real:0.55, D_fake:0.49, C_real:6.00, G_D_fake:2.88, G_C_fake:6.63,
# Iter:  948, Data:7.43, Time:8.56, D_real:0.74, D_fake:0.41, C_real:6.15, G_D_fake:1.74, G_C_fake:6.71,
# Iter:  949, Data:3.41, Time:4.44, D_real:0.46, D_fake:0.93, C_real:6.00, G_D_fake:3.07, G_C_fake:6.51,
# Iter:  950, Data:6.44, Time:7.49, D_real:1.11, D_fake:0.20, C_real:6.08, G_D_fake:1.22, G_C_fake:6.72,
# Iter:  951, Data:13.61, Time:14.64, D_real:0.24, D_fake:1.07, C_real:5.98, G_D_fake:2.76, G_C_fake:6.68,
# Iter:  952, Data:8.26, Time:9.30, D_real:0.53, D_fake:0.37, C_real:5.89, G_D_fake:2.32, G_C_fake:6.68,
# Iter:  953, Data:3.52, Time:4.66, D_real:0.50, D_fake:1.13, C_real:6.03, G_D_fake:3.81, G_C_fake:6.69,
# Iter:  954, Data:8.90, Time:9.94, D_real:1.62, D_fake:0.12, C_real:6.18, G_D_fake:1.45, G_C_fake:6.64,
# Iter:  955, Data:8.47, Time:9.51, D_real:0.43, D_fake:0.97, C_real:6.11, G_D_fake:1.98, G_C_fake:6.75,
# Iter:  956, Data:3.81, Time:4.85, D_real:0.44, D_fake:0.46, C_real:6.04, G_D_fake:2.29, G_C_fake:6.81,
# Iter:  957, Data:21.58, Time:22.73, D_real:0.39, D_fake:0.54, C_real:6.00, G_D_fake:2.39, G_C_fake:6.92,
# Iter:  958, Data:16.05, Time:17.09, D_real:0.54, D_fake:0.40, C_real:6.17, G_D_fake:2.16, G_C_fake:6.81,
# Iter:  959, Data:7.67, Time:8.71, D_real:0.29, D_fake:0.49, C_real:6.22, G_D_fake:2.94, G_C_fake:6.80,
# Iter:  960, Data:17.38, Time:18.63, D_real:0.73, D_fake:0.33, C_real:5.93, G_D_fake:1.93, G_C_fake:6.70,
# Iter:  961, Data:14.35, Time:15.39, D_real:0.54, D_fake:0.73, C_real:6.04, G_D_fake:2.23, G_C_fake:6.70,
# Iter:  962, Data:4.86, Time:5.90, D_real:0.54, D_fake:0.37, C_real:5.97, G_D_fake:2.12, G_C_fake:6.63,
# Iter:  963, Data:4.08, Time:5.12, D_real:0.32, D_fake:0.38, C_real:6.16, G_D_fake:2.21, G_C_fake:6.70,
# Iter:  964, Data:7.81, Time:8.86, D_real:0.38, D_fake:0.66, C_real:5.86, G_D_fake:2.83, G_C_fake:6.70,
# Iter:  965, Data:26.41, Time:27.63, D_real:0.66, D_fake:0.47, C_real:6.00, G_D_fake:3.04, G_C_fake:6.74,
# Iter:  966, Data:5.61, Time:6.65, D_real:0.61, D_fake:0.34, C_real:5.97, G_D_fake:2.77, G_C_fake:6.66,
# Iter:  967, Data:3.93, Time:4.96, D_real:0.21, D_fake:0.52, C_real:6.06, G_D_fake:4.33, G_C_fake:6.75,
# Iter:  968, Data:16.47, Time:17.63, D_real:0.42, D_fake:0.27, C_real:5.90, G_D_fake:3.50, G_C_fake:6.74,
# Iter:  969, Data:3.67, Time:4.71, D_real:0.45, D_fake:0.72, C_real:5.89, G_D_fake:4.30, G_C_fake:6.78,
# Iter:  970, Data:4.77, Time:5.82, D_real:1.11, D_fake:0.50, C_real:5.86, G_D_fake:2.06, G_C_fake:6.97,
# Iter:  971, Data:43.41, Time:44.54, D_real:0.54, D_fake:0.69, C_real:6.06, G_D_fake:2.58, G_C_fake:6.72,
# Iter:  972, Data:1.84, Time:2.88, D_real:0.46, D_fake:0.52, C_real:6.21, G_D_fake:2.64, G_C_fake:6.60,
# Iter:  973, Data:19.81, Time:20.98, D_real:0.51, D_fake:0.53, C_real:5.99, G_D_fake:2.43, G_C_fake:6.52,
# Iter:  974, Data:10.26, Time:11.30, D_real:0.48, D_fake:0.68, C_real:6.04, G_D_fake:2.54, G_C_fake:6.72,
# Iter:  975, Data:4.06, Time:5.09, D_real:0.62, D_fake:0.45, C_real:5.97, G_D_fake:2.11, G_C_fake:6.55,
# Iter:  976, Data:3.39, Time:4.42, D_real:0.42, D_fake:0.67, C_real:6.08, G_D_fake:3.02, G_C_fake:6.57,
# Iter:  977, Data:13.45, Time:14.48, D_real:0.69, D_fake:0.15, C_real:6.07, G_D_fake:1.93, G_C_fake:6.76,
# Iter:  978, Data:4.88, Time:5.99, D_real:0.25, D_fake:0.43, C_real:6.02, G_D_fake:1.93, G_C_fake:6.73,
# Iter:  979, Data:4.23, Time:5.26, D_real:0.21, D_fake:0.45, C_real:5.96, G_D_fake:2.84, G_C_fake:6.72,
# Iter:  980, Data:5.34, Time:6.38, D_real:0.45, D_fake:0.29, C_real:6.03, G_D_fake:2.63, G_C_fake:6.69,
# Iter:  981, Data:12.97, Time:14.00, D_real:0.72, D_fake:0.30, C_real:5.96, G_D_fake:1.51, G_C_fake:6.62,
# Iter:  982, Data:3.89, Time:4.93, D_real:0.35, D_fake:1.00, C_real:5.88, G_D_fake:2.81, G_C_fake:6.67,
# Iter:  983, Data:4.27, Time:5.31, D_real:1.03, D_fake:0.31, C_real:6.11, G_D_fake:1.47, G_C_fake:6.63,
# Iter:  984, Data:56.30, Time:57.43, D_real:0.60, D_fake:1.15, C_real:6.04, G_D_fake:3.31, G_C_fake:6.85,
# Iter:  985, Data:24.54, Time:25.78, D_real:1.57, D_fake:0.17, C_real:6.14, G_D_fake:1.25, G_C_fake:6.69,
# Iter:  986, Data:11.24, Time:12.27, D_real:0.40, D_fake:0.89, C_real:5.88, G_D_fake:2.46, G_C_fake:6.63,
# Iter:  987, Data:23.66, Time:24.88, D_real:0.49, D_fake:0.29, C_real:5.87, G_D_fake:2.64, G_C_fake:6.78,
# Iter:  988, Data:17.17, Time:18.20, D_real:0.46, D_fake:0.34, C_real:6.10, G_D_fake:2.54, G_C_fake:6.76,
# Iter:  989, Data:10.18, Time:11.37, D_real:0.40, D_fake:0.37, C_real:5.88, G_D_fake:2.65, G_C_fake:7.04,
# Iter:  990, Data:21.27, Time:22.30, D_real:0.45, D_fake:0.38, C_real:5.99, G_D_fake:2.89, G_C_fake:6.67,
# Iter:  991, Data:13.14, Time:14.17, D_real:0.70, D_fake:0.34, C_real:6.06, G_D_fake:1.84, G_C_fake:6.61,
# Iter:  992, Data:3.77, Time:4.80, D_real:0.47, D_fake:0.73, C_real:5.93, G_D_fake:3.10, G_C_fake:6.80,
# Iter:  993, Data:3.67, Time:4.79, D_real:1.07, D_fake:0.29, C_real:6.05, G_D_fake:1.48, G_C_fake:6.73,
# Iter:  994, Data:9.07, Time:10.10, D_real:0.40, D_fake:1.08, C_real:6.00, G_D_fake:2.77, G_C_fake:6.60,
# Iter:  995, Data:26.72, Time:27.75, D_real:0.85, D_fake:0.32, C_real:6.02, G_D_fake:2.06, G_C_fake:6.66,
# Iter:  996, Data:14.14, Time:15.40, D_real:0.40, D_fake:0.53, C_real:5.99, G_D_fake:1.72, G_C_fake:6.75,
# Iter:  997, Data:21.29, Time:22.47, D_real:0.29, D_fake:0.63, C_real:5.97, G_D_fake:2.20, G_C_fake:6.64,
# Iter:  998, Data:29.64, Time:30.79, D_real:0.38, D_fake:0.50, C_real:5.95, G_D_fake:2.46, G_C_fake:6.64,
# Iter:  999, Data:3.67, Time:4.70, D_real:0.52, D_fake:0.52, C_real:6.01, G_D_fake:1.99, G_C_fake:6.82,

# %%
#print(generator_losses)
#print(discriminator_losses)
#print(x_axis)
#print(times)

# %%
epochs = range(1, len(x_axis) + 1)
import matplotlib.pyplot as plt
df = pd.read_csv('loss.csv')
plt.plot(df["Epoch"], df["Generator loss"], 'b', label='Generator loss')
plt.plot(df["Epoch"], df["Discriminator loss"], 'r', label='Discriminator loss')
plt.title('Training loss')
plt.legend()
plt.show()

# %% [markdown]
# # Test

# %%
import os
import torch
import shutil
import numpy as np
import torch.nn.functional as F

from PIL import Image
from scipy.io import wavfile
from torch.utils.data.dataloader import default_collate
from vad import read_wave, write_wave, frame_generator, vad_collector


class Meter(object):
    # Computes and stores the average and current value
    def __init__(self, name, display, fmt=':f'):
        self.name = name
        self.display = display
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name}:{' + self.display + self.fmt + '},'
        return fmtstr.format(**self.__dict__)


def get_collate_fn(nframe_range):
    def collate_fn(batch):
        min_nframe, max_nframe = nframe_range
        assert min_nframe <= max_nframe
        num_frame = np.random.randint(min_nframe, max_nframe+1)
        pt = np.random.randint(0, max_nframe-num_frame+1)
        batch = [(item[0][..., pt:pt+num_frame], item[1])for item in batch]
        return default_collate(batch)
    return collate_fn


def cycle(dataloader):
    while True:
        for data, label in dataloader:
            yield data, label


def save_model(net, model_path):
    model_dir = os.path.dirname(model_path)
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    torch.save(net.state_dict(), model_path)


def rm_sil(voice_file, vad_obj):
    """
       This code snippet is basically taken from the repository
           'https://github.com/wiseman/py-webrtcvad'

       It removes the silence clips in a speech recording
    """
    audio, sample_rate = read_wave(voice_file)
    frames = frame_generator(20, audio, sample_rate)
    frames = list(frames)
    segments = vad_collector(sample_rate, 20, 50, vad_obj, frames)

    if os.path.exists('tmp/'):
        shutil.rmtree('tmp/')
    os.makedirs('tmp/')

    wave_data = []
    for i, segment in enumerate(segments):
        segment_file = 'tmp/' + str(i) + '.wav'
        write_wave(segment_file, segment, sample_rate)
        wave_data.append(wavfile.read(segment_file)[1])
    #print("Finshed writing the voice recording to the file")
    shutil.rmtree('tmp/')

    if wave_data:
        #print("The voice recording is not empty")
        vad_voice = np.concatenate(wave_data).astype('int16')
    return vad_voice


def get_fbank(voice, mfc_obj):
    # Extract log mel-spectrogra
    fbank = mfc_obj.sig2logspec(voice).astype('float32')
    #print("The shape of the log mel-spectrogram is: ", fbank.shape)
    # Mean and variance normalization of each mel-frequency
    fbank = fbank - fbank.mean(axis=0)
    fbank = fbank / (fbank.std(axis=0)+np.finfo(np.float32).eps)

    # If the duration of a voice recording is less than 10 seconds (1000 frames),
    # repeat the recording until it is longer than 10 seconds and crop.
    full_frame_number = 1000
    init_frame_number = fbank.shape[0]
    while fbank.shape[0] < full_frame_number:
        fbank = np.append(fbank, fbank[0:init_frame_number], axis=0)
        fbank = fbank[0:full_frame_number, :]
    #print("fbank returned")
    return fbank


def voice2face(e_net, g_net, voice_file, vad_obj, mfc_obj, GPU=True):
    vad_voice = rm_sil(voice_file, vad_obj)
    #print("The shape of the voice recording is: ", vad_voice.shape)
    fbank = get_fbank(vad_voice, mfc_obj)
    #print("The shape of the log mel-spectrogram is: ", fbank.shape)
    fbank = fbank.T[np.newaxis, ...]
    fbank = torch.from_numpy(fbank.astype('float32'))

    if GPU:
        fbank = fbank.cuda()
    embedding = e_net(fbank)
    embedding = F.normalize(embedding)
    face = g_net(embedding)
    return face

# %%
import os
import glob
import torch
import torchvision.utils as vutils
import webrtcvad
from mfcc import MFCC

# %%
# initialization
vad_obj = webrtcvad.Vad(2)
mfc_obj = MFCC(nfilt=64, lowerf=20., upperf=7200., samprate=16000, nfft=1024, wlen=0.025)
e_net, _ = get_network('e', NETWORKS_PARAMETERS, train=False)
g_net, _ = get_network('g', NETWORKS_PARAMETERS, train=False)
# Out:
# load model from pretrained_models/voice_embedding.pth
# load model from models/generator.pth
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 5
#       3 mfc_obj = MFCC(nfilt=64, lowerf=20., upperf=7200., samprate=16000, nfft=1024, wlen=0.025)
#       4 e_net, _ = get_network('e', NETWORKS_PARAMETERS, train=False)
# ----> 5 g_net, _ = get_network('g', NETWORKS_PARAMETERS, train=False)
#
# Cell In[1], line 113, in get_network(net_type, params, train)
#     111     net.eval()
#     112     print('load model from {}'.format(net_params['model_path']))
# --> 113     net.load_state_dict(torch.load(net_params['model_path'],map_location=torch.device('cpu')))
#     114     optimizer = None
#     116 return net, optimizer
#
# File c:\Users\Ahmed\.conda\envs\tensorflow-gpu\lib\site-packages\torch\serialization.py:777, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     772 if _is_zipfile(opened_file):
#     773     # The zipfile reader is going to advance the current file position.
#     774     # If we want to actually tail call to torch.jit.load, we need to
#     775     # reset back to the original position.
#     776     orig_position = opened_file.tell()
# --> 777     with _open_zipfile_reader(opened_file) as opened_zipfile:
#     778         if _is_torchscript_zip(opened_zipfile):
#     779             warnings.warn("'torch.load' received a zip file that looks like a TorchScript archive"
#     780                           " dispatching to 'torch.jit.load' (call 'torch.jit.load' directly to"
#     781                           " silence this warning)", UserWarning)
#
# File c:\Users\Ahmed\.conda\envs\tensorflow-gpu\lib\site-packages\torch\serialization.py:282, in _open_zipfile_reader.__init__(self, name_or_buffer)
#     281 def __init__(self, name_or_buffer) -> None:
# --> 282     super(_open_zipfile_reader, self).__init__(torch._C.PyTorchFileReader(name_or_buffer))
#
# RuntimeError: PytorchStreamReader failed reading zip archive: failed finding central directory

# %%
# test
voice_path = os.path.join(DATASET_PARAMETERS['test_data'], '*.wav')
voice_list = glob.glob(voice_path)
for filename in voice_list:
    print(filename)
    face_image = voice2face(e_net, g_net, filename, vad_obj, mfc_obj,NETWORKS_PARAMETERS['GPU'])
    vutils.save_image(face_image.detach().clamp(-1,1),filename.replace('.wav', '.png'), normalize=True)
# Out:
# data\example_data\2_t1.wav
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[29], line 6
#       4 for filename in voice_list:
#       5     print(filename)
# ----> 6     face_image = voice2face(e_net, g_net, filename, vad_obj, mfc_obj,NETWORKS_PARAMETERS['GPU'])
#       7     vutils.save_image(face_image.detach().clamp(-1,1),filename.replace('.wav', '.png'), normalize=True)
#
# Cell In[18], line 112, in voice2face(e_net, g_net, voice_file, vad_obj, mfc_obj, GPU)
#     111 def voice2face(e_net, g_net, voice_file, vad_obj, mfc_obj, GPU=True):
# --> 112     vad_voice = rm_sil(voice_file, vad_obj)
#     113     #print("The shape of the voice recording is: ", vad_voice.shape)
#     114     fbank = get_fbank(vad_voice, mfc_obj)
#
# Cell In[18], line 69, in rm_sil(voice_file, vad_obj)
#      62 def rm_sil(voice_file, vad_obj):
#      63     """
#      64        This code snippet is basically taken from the repository
#      65            'https://github.com/wiseman/py-webrtcvad'
#      66
#      67        It removes the silence clips in a speech recording
#      68     """
# ---> 69     audio, sample_rate = read_wave(voice_file)
#      70     frames = frame_generator(20, audio, sample_rate)
#      71     frames = list(frames)
#
# File d:\Nourhan\GP\GP_Cloned_repo\reconstructing_faces_from_voices\vad.py:9, in read_wave(path)
#       7 def read_wave(path):
#       8     # print("read_wave")
# ----> 9     with contextlib.closing(wave.open(path, 'rb')) as wf:
#      10         num_channels = wf.getnchannels()
#      11         assert num_channels == 1
#
# File c:\Users\Ahmed\.conda\envs\tensorflow-gpu\lib\wave.py:510, in open(f, mode)
#     508         mode = 'rb'
#     509 if mode in ('r', 'rb'):
# --> 510     return Wave_read(f)
#     511 elif mode in ('w', 'wb'):
#     512     return Wave_write(f)
#
# File c:\Users\Ahmed\.conda\envs\tensorflow-gpu\lib\wave.py:164, in Wave_read.__init__(self, f)
#     162 # else, assume it is an open file object already
#     163 try:
# --> 164     self.initfp(f)
#     165 except:
#     166     if self._i_opened_the_file:
#
# File c:\Users\Ahmed\.conda\envs\tensorflow-gpu\lib\wave.py:144, in Wave_read.initfp(self, file)
#     142 chunkname = chunk.getname()
#     143 if chunkname == b'fmt ':
# --> 144     self._read_fmt_chunk(chunk)
#     145     self._fmt_chunk_read = 1
#     146 elif chunkname == b'data':
#
# File c:\Users\Ahmed\.conda\envs\tensorflow-gpu\lib\wave.py:269, in Wave_read._read_fmt_chunk(self, chunk)
#     267         raise Error('bad sample width')
#     268 else:
# --> 269     raise Error('unknown format: %r' % (wFormatTag,))
#     270 if not self._nchannels:
#     271     raise Error('bad # of channels')
#
# Error: unknown format: 3

# %%
filename = 'voices-for-preprocessing\\2_t1.wav'
face_image = voice2face(e_net, g_net, filename, vad_obj, mfc_obj,True)
vutils.save_image(face_image.detach().clamp(-1,1),filename.replace('.wav', '.png'), normalize=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 filename = 'voices-for-preprocessing\\2_t1.wav'
# ----> 2 face_image = voice2face(e_net, g_net, filename, vad_obj, mfc_obj,True)
#       3 vutils.save_image(face_image.detach().clamp(-1,1),filename.replace('.wav', '.png'), normalize=True)
#
# NameError: name 'g_net' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("loss.csv")

# %%
df.head()
# Out:
#    Epoch  Generator loss  Discriminator loss
# 0      0        4.466321            0.442925
# 1      1        7.062846            1.667645
# 2      2        6.166886            0.742577
# 3      3        2.388814            1.691808
# 4      4        3.505224            2.803046

# %%
gl = []
dl = []
for i in range(0 , len(df),5):
    g = df.iloc[i:i+5,1].mean()
    d = df.iloc[i:i+5,2].mean()
    gl.append(g)
    dl.append(d)

# %%
n = range(1, len(gl) + 1)
import matplotlib.pyplot as plt
df = pd.read_csv('loss.csv')
plt.plot(n, gl, 'b', label='Generator loss')
plt.plot (n, dl, 'r', label='Discriminator loss')
plt.title('Training loss')
plt.legend()
plt.show()

# %%
gl = []
dl = []
for i in range(0 , len(df),10):
    g = df.iloc[i:i+10,1].mean()
    d = df.iloc[i:i+10,2].mean()
    gl.append(g)
    dl.append(d)
    
    
n = range(1, len(gl) + 1)
import matplotlib.pyplot as plt
df = pd.read_csv('loss.csv')
plt.plot(n, gl, 'b', label='Generator loss')
plt.plot (n, dl, 'r', label='Discriminator loss')
plt.title('Training loss')
plt.legend()
plt.show()

# %%
gl = []
dl = []
for i in range(0 , len(df),50):
    g = df.iloc[i:i+50,1].mean()
    d = df.iloc[i:i+50,2].mean()
    gl.append(g)
    dl.append(d)
    
    
n = range(1, len(gl) + 1)
import matplotlib.pyplot as plt
df = pd.read_csv('loss.csv')
plt.plot(n, gl, 'b', label='Generator loss')
plt.plot (n, dl, 'r', label='Discriminator loss')
plt.title('Training loss')
plt.legend()
plt.show()
